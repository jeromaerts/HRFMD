# %% [markdown]
# ## Post-process PCR-GLOBWB output to match wflow_sbm grid

# %% [markdown]
# # ADJUST USING NEW DATA

# %%
import warnings
warnings.filterwarnings("ignore", category=UserWarning)
warnings.filterwarnings("ignore", category=DeprecationWarning)

# %%
from glob import glob
from pathlib import Path

import os
import iris
import xarray as xr
import pandas as pd
from esmvalcore.preprocessor import regrid
from pathos.threading import ThreadPool as Pool
from dask.diagnostics import ProgressBar

# %% [markdown]
# ## Set Paths

# %%
# Set Paths
ROOT = Path('/gpfs/work1/0/wtrcycle/users/jaerts/model_refinement_pub/')
MODELS = Path(f'{ROOT}/model_parameters/')
AUXDIR = Path(f'{ROOT}/aux_data/')
RESULTS = Path(f"{ROOT}/results/streamflow_evaluation/wflow_sbm_calibration/")
OUTPUT = Path(f'{ROOT}/results/')

# %% [markdown]
# ## Config

# %%
# Get available basin IDs wflow_sbm
calibration_file = f"{RESULTS}/wflow_calibration_objective_function_overview.csv"
df = pd.read_csv(calibration_file, index_col='basin_id')
basin_ids = df.index.to_list()

# Amount of available cores
cores_available = 1

# %% [markdown]
# ## Convert saturation degree to volumetric soil moisture

# %%
# Multiply sat degree with porosity layer
soil_layer = f'{AUXDIR}/pcr-globwb/VMC/vmcSat_average_1_europe_30sec_v2.nc'
out_layer  = f'{MODELS}/pcr-globwb/uk_spinup_traveltime/netcdf/satDegUpp_dailyTot_output.nc'

ds_soil = xr.open_dataset(soil_layer).satVolWC1
ds_soil = ds_soil.rename({'latitude':'lat','longitude':'lon'})
ds_out = xr.open_dataset(out_layer).upper_soil_saturation_degree

ds_vmc = xr.Dataset()
ds_vmc['soil_moisture'] = ds_soil * ds_out
ds_vmc.to_netcdf(f'{MODELS}/pcr-globwb/uk_spinup_traveltime/netcdf/satDegUpp_VMC_dailyTot_output.nc')

# %% [markdown]
# ## Post-process pcr-globwb soil moisture output (satDegUp)

# %%
def post_sm_output(basin_id):
    
    # Set basin directory
    BASINDIR = f'{MODELS}/wflow_sbm/{basin_id}/'

    # Open netCDF file as an example grid from the model directory
    cube_example = iris.load(f'{BASINDIR}/staticmaps.nc')[1]

    # Guess bounds   
    cube_example.coord('y').guess_bounds()
    cube_example.coord('x').guess_bounds()

    # Rename Coords
    cube_example.coord('y').rename('latitude')
    cube_example.coord('x').rename('longitude')

    cube_example.coord('latitude').units = 'degrees'
    cube_example.coord('longitude').units = 'degrees'

    # Load output netCDF files
    soil_file = f'{MODELS}/pcr-globwb/uk_spinup_traveltime/netcdf/satDegUpp_VMC_dailyTot_output.nc'

    # Load output
    cube_sim = iris.load(soil_file,'soil_moisture')[0]

    # Guess bounds   
    cube_sim.coord('latitude').guess_bounds()
    cube_sim.coord('longitude').guess_bounds()

    # Regrid observation cube
    cube_out = regrid(cube_sim, cube_example, scheme='area_weighted')

    # Create obs dataset
    da = xr.DataArray.from_iris(cube_out)

    # Create mask dataset
    mask = xr.open_dataset(f'{BASINDIR}/staticmaps.nc').mask
    mask = mask.rename({'y':'latitude','x':'longitude'})

    # Apply mask
    da = da.where(mask>0)

    # Calculate time series
    da = da.mean(['latitude','longitude'])
    da = da.chunk(chunks='auto')
    da = da.drop('spatial_ref')

    # Select time series that matches ref obs
    da = da.sel(time=slice('2015','2017'))

    # Output filename
    output_fname = f'{OUTPUT}/soil_moisture_evaluation/regridded_pcr-globwb_sm/{basin_id}_pcr-globwb_sm_2015_2017.nc'

    # Save to netcdf
    write_job = da.to_netcdf(output_fname, compute=False)
    with ProgressBar():
        write_job.compute()
    
    return print(f'{basin_id} finished: {output_fname}')

# %% [markdown]
# ## Parellel run function

# %%
def parallel_run_sm(
    basin_ids,
    threads=cores_available,
    ):
    
    # Set number of threads (cores) used for parallel run and map threads
    if threads is None:
        pool = Pool()
    else:
        pool = Pool(nodes=threads)
    # Run parallel models
    pool.map(
        post_sm_output,
        basin_ids,
        )
    return

# %% [markdown]
# ## Sort basins by size

# %%
# Sort by basin size
def sort_basin_ids_by_size(basin_ids):
    sizes = []
    for basin_id in basin_ids:
        size = os.path.getsize(f'{MODELS}/wflow_sbm/{basin_id}/staticmaps.nc')
        sizes.append(size)

    df = pd.DataFrame()
    df['basin_id'] = basin_ids
    df['size'] = sizes
    df = df.sort_values('size')

    basin_ids = df.basin_id.to_list()
    
    return basin_ids

basin_ids_sorted = sort_basin_ids_by_size(basin_ids)

# %% [markdown]
# ## Run parallel function

# %%
# Run function
# parallel_run_sm(basin_ids_sorted)
parallel_run_sm(basin_ids)
# Out:
# [########################################] | 100% Completed |  4.7s
# 10003 finished: /gpfs/work1/0/wtrcycle/users/jaerts/model_refinement_pub/results/soil_moisture_evaluation/regridded_pcr-globwb_sm/10003_pcr-globwb_sm_2015_2017.nc
# [########################################] | 100% Completed |  3.3s
# 1001 finished: /gpfs/work1/0/wtrcycle/users/jaerts/model_refinement_pub/results/soil_moisture_evaluation/regridded_pcr-globwb_sm/1001_pcr-globwb_sm_2015_2017.nc
# [########################################] | 100% Completed |  3.4s
# 101002 finished: /gpfs/work1/0/wtrcycle/users/jaerts/model_refinement_pub/results/soil_moisture_evaluation/regridded_pcr-globwb_sm/101002_pcr-globwb_sm_2015_2017.nc
# [########################################] | 100% Completed |  2.9s
# 101005 finished: /gpfs/work1/0/wtrcycle/users/jaerts/model_refinement_pub/results/soil_moisture_evaluation/regridded_pcr-globwb_sm/101005_pcr-globwb_sm_2015_2017.nc
# [########################################] | 100% Completed |  2.9s
# 102001 finished: /gpfs/work1/0/wtrcycle/users/jaerts/model_refinement_pub/results/soil_moisture_evaluation/regridded_pcr-globwb_sm/102001_pcr-globwb_sm_2015_2017.nc
# [########################################] | 100% Completed |  3.1s
# 106001 finished: /gpfs/work1/0/wtrcycle/users/jaerts/model_refinement_pub/results/soil_moisture_evaluation/regridded_pcr-globwb_sm/106001_pcr-globwb_sm_2015_2017.nc
# [########################################] | 100% Completed |  3.1s
# 107001 finished: /gpfs/work1/0/wtrcycle/users/jaerts/model_refinement_pub/results/soil_moisture_evaluation/regridded_pcr-globwb_sm/107001_pcr-globwb_sm_2015_2017.nc
# [########################################] | 100% Completed |  5.3s
# 11001 finished: /gpfs/work1/0/wtrcycle/users/jaerts/model_refinement_pub/results/soil_moisture_evaluation/regridded_pcr-globwb_sm/11001_pcr-globwb_sm_2015_2017.nc
# [########################################] | 100% Completed |  3.6s
# 11003 finished: /gpfs/work1/0/wtrcycle/users/jaerts/model_refinement_pub/results/soil_moisture_evaluation/regridded_pcr-globwb_sm/11003_pcr-globwb_sm_2015_2017.nc
# [########################################] | 100% Completed |  3.0s
# 11004 finished: /gpfs/work1/0/wtrcycle/users/jaerts/model_refinement_pub/results/soil_moisture_evaluation/regridded_pcr-globwb_sm/11004_pcr-globwb_sm_2015_2017.nc
# [########################################] | 100% Completed |  5.2s
# 12001 finished: /gpfs/work1/0/wtrcycle/users/jaerts/model_refinement_pub/results/soil_moisture_evaluation/regridded_pcr-globwb_sm/12001_pcr-globwb_sm_2015_2017.nc
# [########################################] | 100% Completed |  7.7s
# 12002 finished: /gpfs/work1/0/wtrcycle/users/jaerts/model_refinement_pub/results/soil_moisture_evaluation/regridded_pcr-globwb_sm/12002_pcr-globwb_sm_2015_2017.nc
# [########################################] | 100% Completed |  3.9s
# 12005 finished: /gpfs/work1/0/wtrcycle/users/jaerts/model_refinement_pub/results/soil_moisture_evaluation/regridded_pcr-globwb_sm/12005_pcr-globwb_sm_2015_2017.nc
# [########################################] | 100% Completed |  2.9s
# 12006 finished: /gpfs/work1/0/wtrcycle/users/jaerts/model_refinement_pub/results/soil_moisture_evaluation/regridded_pcr-globwb_sm/12006_pcr-globwb_sm_2015_2017.nc
# [########################################] | 100% Completed |  3.5s
# 12007 finished: /gpfs/work1/0/wtrcycle/users/jaerts/model_refinement_pub/results/soil_moisture_evaluation/regridded_pcr-globwb_sm/12007_pcr-globwb_sm_2015_2017.nc
# [########################################] | 100% Completed |  3.4s
# 12008 finished: /gpfs/work1/0/wtrcycle/users/jaerts/model_refinement_pub/results/soil_moisture_evaluation/regridded_pcr-globwb_sm/12008_pcr-globwb_sm_2015_2017.nc
# [########################################] | 100% Completed |  3.0s
# 12009 finished: /gpfs/work1/0/wtrcycle/users/jaerts/model_refinement_pub/results/soil_moisture_evaluation/regridded_pcr-globwb_sm/12009_pcr-globwb_sm_2015_2017.nc
# [########################################] | 100% Completed |  3.0s
# 13001 finished: /gpfs/work1/0/wtrcycle/users/jaerts/model_refinement_pub/results/soil_moisture_evaluation/regridded_pcr-globwb_sm/13001_pcr-globwb_sm_2015_2017.nc
# [########################################] | 100% Completed |  2.9s
# 13004 finished: /gpfs/work1/0/wtrcycle/users/jaerts/model_refinement_pub/results/soil_moisture_evaluation/regridded_pcr-globwb_sm/13004_pcr-globwb_sm_2015_2017.nc
# [########################################] | 100% Completed |  2.8s
# 13005 finished: /gpfs/work1/0/wtrcycle/users/jaerts/model_refinement_pub/results/soil_moisture_evaluation/regridded_pcr-globwb_sm/13005_pcr-globwb_sm_2015_2017.nc
# [########################################] | 100% Completed |  3.9s
# 13007 finished: /gpfs/work1/0/wtrcycle/users/jaerts/model_refinement_pub/results/soil_moisture_evaluation/regridded_pcr-globwb_sm/13007_pcr-globwb_sm_2015_2017.nc
# [########################################] | 100% Completed |  4.1s
# 13008 finished: /gpfs/work1/0/wtrcycle/users/jaerts/model_refinement_pub/results/soil_moisture_evaluation/regridded_pcr-globwb_sm/13008_pcr-globwb_sm_2015_2017.nc
# [########################################] | 100% Completed |  3.6s
# 14001 finished: /gpfs/work1/0/wtrcycle/users/jaerts/model_refinement_pub/results/soil_moisture_evaluation/regridded_pcr-globwb_sm/14001_pcr-globwb_sm_2015_2017.nc
# [########################################] | 100% Completed |  3.2s
# 14002 finished: /gpfs/work1/0/wtrcycle/users/jaerts/model_refinement_pub/results/soil_moisture_evaluation/regridded_pcr-globwb_sm/14002_pcr-globwb_sm_2015_2017.nc
# [########################################] | 100% Completed |  2.8s
# 14005 finished: /gpfs/work1/0/wtrcycle/users/jaerts/model_refinement_pub/results/soil_moisture_evaluation/regridded_pcr-globwb_sm/14005_pcr-globwb_sm_2015_2017.nc
# [########################################] | 100% Completed | 11.0s
# 15006 finished: /gpfs/work1/0/wtrcycle/users/jaerts/model_refinement_pub/results/soil_moisture_evaluation/regridded_pcr-globwb_sm/15006_pcr-globwb_sm_2015_2017.nc
# [########################################] | 100% Completed |  5.9s
# 15007 finished: /gpfs/work1/0/wtrcycle/users/jaerts/model_refinement_pub/results/soil_moisture_evaluation/regridded_pcr-globwb_sm/15007_pcr-globwb_sm_2015_2017.nc
# [########################################] | 100% Completed |  3.1s
# 15010 finished: /gpfs/work1/0/wtrcycle/users/jaerts/model_refinement_pub/results/soil_moisture_evaluation/regridded_pcr-globwb_sm/15010_pcr-globwb_sm_2015_2017.nc
# [########################################] | 100% Completed |  3.5s
# 15011 finished: /gpfs/work1/0/wtrcycle/users/jaerts/model_refinement_pub/results/soil_moisture_evaluation/regridded_pcr-globwb_sm/15011_pcr-globwb_sm_2015_2017.nc
# [########################################] | 100% Completed |  6.1s
# 15012 finished: /gpfs/work1/0/wtrcycle/users/jaerts/model_refinement_pub/results/soil_moisture_evaluation/regridded_pcr-globwb_sm/15012_pcr-globwb_sm_2015_2017.nc
# [########################################] | 100% Completed |  3.3s
# 15013 finished: /gpfs/work1/0/wtrcycle/users/jaerts/model_refinement_pub/results/soil_moisture_evaluation/regridded_pcr-globwb_sm/15013_pcr-globwb_sm_2015_2017.nc
# [########################################] | 100% Completed |  2.7s
# 15014 finished: /gpfs/work1/0/wtrcycle/users/jaerts/model_refinement_pub/results/soil_moisture_evaluation/regridded_pcr-globwb_sm/15014_pcr-globwb_sm_2015_2017.nc
# [########################################] | 100% Completed |  3.9s
# 15016 finished: /gpfs/work1/0/wtrcycle/users/jaerts/model_refinement_pub/results/soil_moisture_evaluation/regridded_pcr-globwb_sm/15016_pcr-globwb_sm_2015_2017.nc
# [########################################] | 100% Completed |  2.9s
# 15021 finished: /gpfs/work1/0/wtrcycle/users/jaerts/model_refinement_pub/results/soil_moisture_evaluation/regridded_pcr-globwb_sm/15021_pcr-globwb_sm_2015_2017.nc
# [########################################] | 100% Completed |  2.8s
# 15023 finished: /gpfs/work1/0/wtrcycle/users/jaerts/model_refinement_pub/results/soil_moisture_evaluation/regridded_pcr-globwb_sm/15023_pcr-globwb_sm_2015_2017.nc
# [########################################] | 100% Completed |  2.8s
# 15024 finished: /gpfs/work1/0/wtrcycle/users/jaerts/model_refinement_pub/results/soil_moisture_evaluation/regridded_pcr-globwb_sm/15024_pcr-globwb_sm_2015_2017.nc
# [########################################] | 100% Completed |  3.2s
# 15025 finished: /gpfs/work1/0/wtrcycle/users/jaerts/model_refinement_pub/results/soil_moisture_evaluation/regridded_pcr-globwb_sm/15025_pcr-globwb_sm_2015_2017.nc
# [########################################] | 100% Completed |  2.9s
# 15030 finished: /gpfs/work1/0/wtrcycle/users/jaerts/model_refinement_pub/results/soil_moisture_evaluation/regridded_pcr-globwb_sm/15030_pcr-globwb_sm_2015_2017.nc
# [########################################] | 100% Completed |  2.9s
# 15039 finished: /gpfs/work1/0/wtrcycle/users/jaerts/model_refinement_pub/results/soil_moisture_evaluation/regridded_pcr-globwb_sm/15039_pcr-globwb_sm_2015_2017.nc
# [########################################] | 100% Completed |  3.4s
# 16001 finished: /gpfs/work1/0/wtrcycle/users/jaerts/model_refinement_pub/results/soil_moisture_evaluation/regridded_pcr-globwb_sm/16001_pcr-globwb_sm_2015_2017.nc
# [########################################] | 100% Completed |  2.6s
# 16003 finished: /gpfs/work1/0/wtrcycle/users/jaerts/model_refinement_pub/results/soil_moisture_evaluation/regridded_pcr-globwb_sm/16003_pcr-globwb_sm_2015_2017.nc
# [########################################] | 100% Completed |  3.8s
# 16004 finished: /gpfs/work1/0/wtrcycle/users/jaerts/model_refinement_pub/results/soil_moisture_evaluation/regridded_pcr-globwb_sm/16004_pcr-globwb_sm_2015_2017.nc
# [########################################] | 100% Completed |  3.1s
# 17001 finished: /gpfs/work1/0/wtrcycle/users/jaerts/model_refinement_pub/results/soil_moisture_evaluation/regridded_pcr-globwb_sm/17001_pcr-globwb_sm_2015_2017.nc
# [########################################] | 100% Completed |  2.6s
# 17003 finished: /gpfs/work1/0/wtrcycle/users/jaerts/model_refinement_pub/results/soil_moisture_evaluation/regridded_pcr-globwb_sm/17003_pcr-globwb_sm_2015_2017.nc
# [########################################] | 100% Completed |  2.6s
# 17004 finished: /gpfs/work1/0/wtrcycle/users/jaerts/model_refinement_pub/results/soil_moisture_evaluation/regridded_pcr-globwb_sm/17004_pcr-globwb_sm_2015_2017.nc
# [########################################] | 100% Completed |  3.2s
# 17005 finished: /gpfs/work1/0/wtrcycle/users/jaerts/model_refinement_pub/results/soil_moisture_evaluation/regridded_pcr-globwb_sm/17005_pcr-globwb_sm_2015_2017.nc
# [########################################] | 100% Completed |  2.4s
# 17015 finished: /gpfs/work1/0/wtrcycle/users/jaerts/model_refinement_pub/results/soil_moisture_evaluation/regridded_pcr-globwb_sm/17015_pcr-globwb_sm_2015_2017.nc
# [########################################] | 100% Completed |  2.9s
# 18001 finished: /gpfs/work1/0/wtrcycle/users/jaerts/model_refinement_pub/results/soil_moisture_evaluation/regridded_pcr-globwb_sm/18001_pcr-globwb_sm_2015_2017.nc
# [########################################] | 100% Completed |  2.8s
# 18002 finished: /gpfs/work1/0/wtrcycle/users/jaerts/model_refinement_pub/results/soil_moisture_evaluation/regridded_pcr-globwb_sm/18002_pcr-globwb_sm_2015_2017.nc
# [########################################] | 100% Completed |  3.4s
# 18003 finished: /gpfs/work1/0/wtrcycle/users/jaerts/model_refinement_pub/results/soil_moisture_evaluation/regridded_pcr-globwb_sm/18003_pcr-globwb_sm_2015_2017.nc
# [########################################] | 100% Completed |  3.1s
# 18008 finished: /gpfs/work1/0/wtrcycle/users/jaerts/model_refinement_pub/results/soil_moisture_evaluation/regridded_pcr-globwb_sm/18008_pcr-globwb_sm_2015_2017.nc
# [########################################] | 100% Completed |  3.0s
# 18010 finished: /gpfs/work1/0/wtrcycle/users/jaerts/model_refinement_pub/results/soil_moisture_evaluation/regridded_pcr-globwb_sm/18010_pcr-globwb_sm_2015_2017.nc
# [########################################] | 100% Completed |  4.3s
# 18011 finished: /gpfs/work1/0/wtrcycle/users/jaerts/model_refinement_pub/results/soil_moisture_evaluation/regridded_pcr-globwb_sm/18011_pcr-globwb_sm_2015_2017.nc
# [########################################] | 100% Completed |  2.7s
# 18014 finished: /gpfs/work1/0/wtrcycle/users/jaerts/model_refinement_pub/results/soil_moisture_evaluation/regridded_pcr-globwb_sm/18014_pcr-globwb_sm_2015_2017.nc
# [########################################] | 100% Completed |  3.3s
# 19001 finished: /gpfs/work1/0/wtrcycle/users/jaerts/model_refinement_pub/results/soil_moisture_evaluation/regridded_pcr-globwb_sm/19001_pcr-globwb_sm_2015_2017.nc
# [########################################] | 100% Completed |  2.9s
# 19006 finished: /gpfs/work1/0/wtrcycle/users/jaerts/model_refinement_pub/results/soil_moisture_evaluation/regridded_pcr-globwb_sm/19006_pcr-globwb_sm_2015_2017.nc
# [########################################] | 100% Completed |  2.5s
# 19010 finished: /gpfs/work1/0/wtrcycle/users/jaerts/model_refinement_pub/results/soil_moisture_evaluation/regridded_pcr-globwb_sm/19010_pcr-globwb_sm_2015_2017.nc
# [########################################] | 100% Completed |  2.5s
# 19017 finished: /gpfs/work1/0/wtrcycle/users/jaerts/model_refinement_pub/results/soil_moisture_evaluation/regridded_pcr-globwb_sm/19017_pcr-globwb_sm_2015_2017.nc
# [########################################] | 100% Completed |  2.6s
# 19020 finished: /gpfs/work1/0/wtrcycle/users/jaerts/model_refinement_pub/results/soil_moisture_evaluation/regridded_pcr-globwb_sm/19020_pcr-globwb_sm_2015_2017.nc
# [########################################] | 100% Completed |  2.5s
# 20002 finished: /gpfs/work1/0/wtrcycle/users/jaerts/model_refinement_pub/results/soil_moisture_evaluation/regridded_pcr-globwb_sm/20002_pcr-globwb_sm_2015_2017.nc
# [########################################] | 100% Completed |  2.7s
# 20003 finished: /gpfs/work1/0/wtrcycle/users/jaerts/model_refinement_pub/results/soil_moisture_evaluation/regridded_pcr-globwb_sm/20003_pcr-globwb_sm_2015_2017.nc
# [########################################] | 100% Completed |  2.8s
# 20007 finished: /gpfs/work1/0/wtrcycle/users/jaerts/model_refinement_pub/results/soil_moisture_evaluation/regridded_pcr-globwb_sm/20007_pcr-globwb_sm_2015_2017.nc
# [########################################] | 100% Completed |  3.4s
# 2001 finished: /gpfs/work1/0/wtrcycle/users/jaerts/model_refinement_pub/results/soil_moisture_evaluation/regridded_pcr-globwb_sm/2001_pcr-globwb_sm_2015_2017.nc
# [########################################] | 100% Completed |  3.3s
# 2002 finished: /gpfs/work1/0/wtrcycle/users/jaerts/model_refinement_pub/results/soil_moisture_evaluation/regridded_pcr-globwb_sm/2002_pcr-globwb_sm_2015_2017.nc
# [########################################] | 100% Completed |  3.7s
# 21003 finished: /gpfs/work1/0/wtrcycle/users/jaerts/model_refinement_pub/results/soil_moisture_evaluation/regridded_pcr-globwb_sm/21003_pcr-globwb_sm_2015_2017.nc
# [########################################] | 100% Completed |  5.1s
# 21006 finished: /gpfs/work1/0/wtrcycle/users/jaerts/model_refinement_pub/results/soil_moisture_evaluation/regridded_pcr-globwb_sm/21006_pcr-globwb_sm_2015_2017.nc
# [########################################] | 100% Completed |  4.5s
# 21008 finished: /gpfs/work1/0/wtrcycle/users/jaerts/model_refinement_pub/results/soil_moisture_evaluation/regridded_pcr-globwb_sm/21008_pcr-globwb_sm_2015_2017.nc
# [########################################] | 100% Completed |  9.2s
# 21009 finished: /gpfs/work1/0/wtrcycle/users/jaerts/model_refinement_pub/results/soil_moisture_evaluation/regridded_pcr-globwb_sm/21009_pcr-globwb_sm_2015_2017.nc
# [########################################] | 100% Completed |  3.9s
# 21011 finished: /gpfs/work1/0/wtrcycle/users/jaerts/model_refinement_pub/results/soil_moisture_evaluation/regridded_pcr-globwb_sm/21011_pcr-globwb_sm_2015_2017.nc
# [########################################] | 100% Completed |  2.7s
# 21012 finished: /gpfs/work1/0/wtrcycle/users/jaerts/model_refinement_pub/results/soil_moisture_evaluation/regridded_pcr-globwb_sm/21012_pcr-globwb_sm_2015_2017.nc
# [########################################] | 100% Completed |  2.9s
# 21013 finished: /gpfs/work1/0/wtrcycle/users/jaerts/model_refinement_pub/results/soil_moisture_evaluation/regridded_pcr-globwb_sm/21013_pcr-globwb_sm_2015_2017.nc
# [########################################] | 100% Completed |  2.7s
# 21015 finished: /gpfs/work1/0/wtrcycle/users/jaerts/model_refinement_pub/results/soil_moisture_evaluation/regridded_pcr-globwb_sm/21015_pcr-globwb_sm_2015_2017.nc
# [########################################] | 100% Completed |  2.8s
# 21016 finished: /gpfs/work1/0/wtrcycle/users/jaerts/model_refinement_pub/results/soil_moisture_evaluation/regridded_pcr-globwb_sm/21016_pcr-globwb_sm_2015_2017.nc
# [########################################] | 100% Completed |  2.8s
# 21017 finished: /gpfs/work1/0/wtrcycle/users/jaerts/model_refinement_pub/results/soil_moisture_evaluation/regridded_pcr-globwb_sm/21017_pcr-globwb_sm_2015_2017.nc
# [########################################] | 100% Completed |  2.8s
# 21018 finished: /gpfs/work1/0/wtrcycle/users/jaerts/model_refinement_pub/results/soil_moisture_evaluation/regridded_pcr-globwb_sm/21018_pcr-globwb_sm_2015_2017.nc
# [########################################] | 100% Completed |  3.4s
# 21022 finished: /gpfs/work1/0/wtrcycle/users/jaerts/model_refinement_pub/results/soil_moisture_evaluation/regridded_pcr-globwb_sm/21022_pcr-globwb_sm_2015_2017.nc
# [########################################] | 100% Completed |  3.0s
# 21023 finished: /gpfs/work1/0/wtrcycle/users/jaerts/model_refinement_pub/results/soil_moisture_evaluation/regridded_pcr-globwb_sm/21023_pcr-globwb_sm_2015_2017.nc
# [########################################] | 100% Completed |  2.7s
# 21024 finished: /gpfs/work1/0/wtrcycle/users/jaerts/model_refinement_pub/results/soil_moisture_evaluation/regridded_pcr-globwb_sm/21024_pcr-globwb_sm_2015_2017.nc
# [########################################] | 100% Completed |  2.4s
# 21026 finished: /gpfs/work1/0/wtrcycle/users/jaerts/model_refinement_pub/results/soil_moisture_evaluation/regridded_pcr-globwb_sm/21026_pcr-globwb_sm_2015_2017.nc
# [########################################] | 100% Completed |  2.8s
# 21027 finished: /gpfs/work1/0/wtrcycle/users/jaerts/model_refinement_pub/results/soil_moisture_evaluation/regridded_pcr-globwb_sm/21027_pcr-globwb_sm_2015_2017.nc
# [########################################] | 100% Completed |  3.6s
# 22001 finished: /gpfs/work1/0/wtrcycle/users/jaerts/model_refinement_pub/results/soil_moisture_evaluation/regridded_pcr-globwb_sm/22001_pcr-globwb_sm_2015_2017.nc
# [########################################] | 100% Completed |  2.8s
# 22006 finished: /gpfs/work1/0/wtrcycle/users/jaerts/model_refinement_pub/results/soil_moisture_evaluation/regridded_pcr-globwb_sm/22006_pcr-globwb_sm_2015_2017.nc
# [########################################] | 100% Completed |  3.3s
# 22007 finished: /gpfs/work1/0/wtrcycle/users/jaerts/model_refinement_pub/results/soil_moisture_evaluation/regridded_pcr-globwb_sm/22007_pcr-globwb_sm_2015_2017.nc
# [########################################] | 100% Completed |  3.2s
# 22009 finished: /gpfs/work1/0/wtrcycle/users/jaerts/model_refinement_pub/results/soil_moisture_evaluation/regridded_pcr-globwb_sm/22009_pcr-globwb_sm_2015_2017.nc
# [########################################] | 100% Completed |  6.3s
# 23001 finished: /gpfs/work1/0/wtrcycle/users/jaerts/model_refinement_pub/results/soil_moisture_evaluation/regridded_pcr-globwb_sm/23001_pcr-globwb_sm_2015_2017.nc
# [########################################] | 100% Completed |  3.9s
# 23004 finished: /gpfs/work1/0/wtrcycle/users/jaerts/model_refinement_pub/results/soil_moisture_evaluation/regridded_pcr-globwb_sm/23004_pcr-globwb_sm_2015_2017.nc
# [########################################] | 100% Completed |  2.9s
# 23006 finished: /gpfs/work1/0/wtrcycle/users/jaerts/model_refinement_pub/results/soil_moisture_evaluation/regridded_pcr-globwb_sm/23006_pcr-globwb_sm_2015_2017.nc
# [########################################] | 100% Completed |  3.3s
# 23007 finished: /gpfs/work1/0/wtrcycle/users/jaerts/model_refinement_pub/results/soil_moisture_evaluation/regridded_pcr-globwb_sm/23007_pcr-globwb_sm_2015_2017.nc
# [########################################] | 100% Completed |  3.4s
# 23008 finished: /gpfs/work1/0/wtrcycle/users/jaerts/model_refinement_pub/results/soil_moisture_evaluation/regridded_pcr-globwb_sm/23008_pcr-globwb_sm_2015_2017.nc
# [########################################] | 100% Completed |  2.5s
# 23011 finished: /gpfs/work1/0/wtrcycle/users/jaerts/model_refinement_pub/results/soil_moisture_evaluation/regridded_pcr-globwb_sm/23011_pcr-globwb_sm_2015_2017.nc
# [########################################] | 100% Completed |  2.7s
# 23016 finished: /gpfs/work1/0/wtrcycle/users/jaerts/model_refinement_pub/results/soil_moisture_evaluation/regridded_pcr-globwb_sm/23016_pcr-globwb_sm_2015_2017.nc
# [########################################] | 100% Completed |  3.4s
# 24001 finished: /gpfs/work1/0/wtrcycle/users/jaerts/model_refinement_pub/results/soil_moisture_evaluation/regridded_pcr-globwb_sm/24001_pcr-globwb_sm_2015_2017.nc
# [########################################] | 100% Completed |  2.8s
# 24003 finished: /gpfs/work1/0/wtrcycle/users/jaerts/model_refinement_pub/results/soil_moisture_evaluation/regridded_pcr-globwb_sm/24003_pcr-globwb_sm_2015_2017.nc
# [########################################] | 100% Completed |  2.5s
# 24004 finished: /gpfs/work1/0/wtrcycle/users/jaerts/model_refinement_pub/results/soil_moisture_evaluation/regridded_pcr-globwb_sm/24004_pcr-globwb_sm_2015_2017.nc
# [########################################] | 100% Completed |  2.8s
# 24005 finished: /gpfs/work1/0/wtrcycle/users/jaerts/model_refinement_pub/results/soil_moisture_evaluation/regridded_pcr-globwb_sm/24005_pcr-globwb_sm_2015_2017.nc
# [########################################] | 100% Completed |  3.9s
# 25001 finished: /gpfs/work1/0/wtrcycle/users/jaerts/model_refinement_pub/results/soil_moisture_evaluation/regridded_pcr-globwb_sm/25001_pcr-globwb_sm_2015_2017.nc
# [########################################] | 100% Completed |  2.5s
# 25003 finished: /gpfs/work1/0/wtrcycle/users/jaerts/model_refinement_pub/results/soil_moisture_evaluation/regridded_pcr-globwb_sm/25003_pcr-globwb_sm_2015_2017.nc
# [########################################] | 100% Completed |  2.6s
# 25006 finished: /gpfs/work1/0/wtrcycle/users/jaerts/model_refinement_pub/results/soil_moisture_evaluation/regridded_pcr-globwb_sm/25006_pcr-globwb_sm_2015_2017.nc
# [########################################] | 100% Completed |  2.4s
# 25012 finished: /gpfs/work1/0/wtrcycle/users/jaerts/model_refinement_pub/results/soil_moisture_evaluation/regridded_pcr-globwb_sm/25012_pcr-globwb_sm_2015_2017.nc
# [########################################] | 100% Completed |  2.7s
# 25020 finished: /gpfs/work1/0/wtrcycle/users/jaerts/model_refinement_pub/results/soil_moisture_evaluation/regridded_pcr-globwb_sm/25020_pcr-globwb_sm_2015_2017.nc
# [########################################] | 100% Completed |  2.6s
# 25021 finished: /gpfs/work1/0/wtrcycle/users/jaerts/model_refinement_pub/results/soil_moisture_evaluation/regridded_pcr-globwb_sm/25021_pcr-globwb_sm_2015_2017.nc
# [########################################] | 100% Completed |  2.6s
# 25029 finished: /gpfs/work1/0/wtrcycle/users/jaerts/model_refinement_pub/results/soil_moisture_evaluation/regridded_pcr-globwb_sm/25029_pcr-globwb_sm_2015_2017.nc
# [########################################] | 100% Completed |  2.7s
# 26003 finished: /gpfs/work1/0/wtrcycle/users/jaerts/model_refinement_pub/results/soil_moisture_evaluation/regridded_pcr-globwb_sm/26003_pcr-globwb_sm_2015_2017.nc
# [########################################] | 100% Completed |  3.0s
# 26005 finished: /gpfs/work1/0/wtrcycle/users/jaerts/model_refinement_pub/results/soil_moisture_evaluation/regridded_pcr-globwb_sm/26005_pcr-globwb_sm_2015_2017.nc
# [########################################] | 100% Completed |  2.4s
# 26006 finished: /gpfs/work1/0/wtrcycle/users/jaerts/model_refinement_pub/results/soil_moisture_evaluation/regridded_pcr-globwb_sm/26006_pcr-globwb_sm_2015_2017.nc
# [########################################] | 100% Completed |  2.8s
# 26008 finished: /gpfs/work1/0/wtrcycle/users/jaerts/model_refinement_pub/results/soil_moisture_evaluation/regridded_pcr-globwb_sm/26008_pcr-globwb_sm_2015_2017.nc
# [########################################] | 100% Completed |  3.0s
# 26009 finished: /gpfs/work1/0/wtrcycle/users/jaerts/model_refinement_pub/results/soil_moisture_evaluation/regridded_pcr-globwb_sm/26009_pcr-globwb_sm_2015_2017.nc
# [########################################] | 100% Completed |  3.9s
# 27001 finished: /gpfs/work1/0/wtrcycle/users/jaerts/model_refinement_pub/results/soil_moisture_evaluation/regridded_pcr-globwb_sm/27001_pcr-globwb_sm_2015_2017.nc
# [########################################] | 100% Completed |  5.1s
# 27002 finished: /gpfs/work1/0/wtrcycle/users/jaerts/model_refinement_pub/results/soil_moisture_evaluation/regridded_pcr-globwb_sm/27002_pcr-globwb_sm_2015_2017.nc
# [########################################] | 100% Completed |  6.8s
# 27003 finished: /gpfs/work1/0/wtrcycle/users/jaerts/model_refinement_pub/results/soil_moisture_evaluation/regridded_pcr-globwb_sm/27003_pcr-globwb_sm_2015_2017.nc
# [########################################] | 100% Completed |  3.7s
# 27006 finished: /gpfs/work1/0/wtrcycle/users/jaerts/model_refinement_pub/results/soil_moisture_evaluation/regridded_pcr-globwb_sm/27006_pcr-globwb_sm_2015_2017.nc
# [########################################] | 100% Completed |  4.8s
# 27007 finished: /gpfs/work1/0/wtrcycle/users/jaerts/model_refinement_pub/results/soil_moisture_evaluation/regridded_pcr-globwb_sm/27007_pcr-globwb_sm_2015_2017.nc
# [########################################] | 100% Completed |  7.9s
# 27009 finished: /gpfs/work1/0/wtrcycle/users/jaerts/model_refinement_pub/results/soil_moisture_evaluation/regridded_pcr-globwb_sm/27009_pcr-globwb_sm_2015_2017.nc
# [########################################] | 100% Completed |  5.5s
# 27021 finished: /gpfs/work1/0/wtrcycle/users/jaerts/model_refinement_pub/results/soil_moisture_evaluation/regridded_pcr-globwb_sm/27021_pcr-globwb_sm_2015_2017.nc
# [########################################] | 100% Completed |  3.0s
# 27023 finished: /gpfs/work1/0/wtrcycle/users/jaerts/model_refinement_pub/results/soil_moisture_evaluation/regridded_pcr-globwb_sm/27023_pcr-globwb_sm_2015_2017.nc
# [########################################] | 100% Completed |  3.4s
# 27025 finished: /gpfs/work1/0/wtrcycle/users/jaerts/model_refinement_pub/results/soil_moisture_evaluation/regridded_pcr-globwb_sm/27025_pcr-globwb_sm_2015_2017.nc
# [########################################] | 100% Completed |  3.0s
# 27026 finished: /gpfs/work1/0/wtrcycle/users/jaerts/model_refinement_pub/results/soil_moisture_evaluation/regridded_pcr-globwb_sm/27026_pcr-globwb_sm_2015_2017.nc
# [########################################] | 100% Completed |  3.3s
# 27029 finished: /gpfs/work1/0/wtrcycle/users/jaerts/model_refinement_pub/results/soil_moisture_evaluation/regridded_pcr-globwb_sm/27029_pcr-globwb_sm_2015_2017.nc
# [########################################] | 100% Completed |  3.0s
# 27030 finished: /gpfs/work1/0/wtrcycle/users/jaerts/model_refinement_pub/results/soil_moisture_evaluation/regridded_pcr-globwb_sm/27030_pcr-globwb_sm_2015_2017.nc
# [########################################] | 100% Completed |  2.5s
# 27032 finished: /gpfs/work1/0/wtrcycle/users/jaerts/model_refinement_pub/results/soil_moisture_evaluation/regridded_pcr-globwb_sm/27032_pcr-globwb_sm_2015_2017.nc
# [########################################] | 100% Completed |  3.5s
# 27034 finished: /gpfs/work1/0/wtrcycle/users/jaerts/model_refinement_pub/results/soil_moisture_evaluation/regridded_pcr-globwb_sm/27034_pcr-globwb_sm_2015_2017.nc
# [########################################] | 100% Completed |  3.0s
# 27035 finished: /gpfs/work1/0/wtrcycle/users/jaerts/model_refinement_pub/results/soil_moisture_evaluation/regridded_pcr-globwb_sm/27035_pcr-globwb_sm_2015_2017.nc
# [########################################] | 100% Completed |  2.5s
# 27038 finished: /gpfs/work1/0/wtrcycle/users/jaerts/model_refinement_pub/results/soil_moisture_evaluation/regridded_pcr-globwb_sm/27038_pcr-globwb_sm_2015_2017.nc
# [########################################] | 100% Completed |  5.6s
# 27041 finished: /gpfs/work1/0/wtrcycle/users/jaerts/model_refinement_pub/results/soil_moisture_evaluation/regridded_pcr-globwb_sm/27041_pcr-globwb_sm_2015_2017.nc
# [########################################] | 100% Completed |  3.5s
# 27042 finished: /gpfs/work1/0/wtrcycle/users/jaerts/model_refinement_pub/results/soil_moisture_evaluation/regridded_pcr-globwb_sm/27042_pcr-globwb_sm_2015_2017.nc
# [########################################] | 100% Completed |  3.6s
# 27043 finished: /gpfs/work1/0/wtrcycle/users/jaerts/model_refinement_pub/results/soil_moisture_evaluation/regridded_pcr-globwb_sm/27043_pcr-globwb_sm_2015_2017.nc
# [########################################] | 100% Completed |  2.6s
# 27047 finished: /gpfs/work1/0/wtrcycle/users/jaerts/model_refinement_pub/results/soil_moisture_evaluation/regridded_pcr-globwb_sm/27047_pcr-globwb_sm_2015_2017.nc
# [########################################] | 100% Completed |  3.0s
# 27049 finished: /gpfs/work1/0/wtrcycle/users/jaerts/model_refinement_pub/results/soil_moisture_evaluation/regridded_pcr-globwb_sm/27049_pcr-globwb_sm_2015_2017.nc
# [########################################] | 100% Completed |  2.7s
# 27051 finished: /gpfs/work1/0/wtrcycle/users/jaerts/model_refinement_pub/results/soil_moisture_evaluation/regridded_pcr-globwb_sm/27051_pcr-globwb_sm_2015_2017.nc
# [########################################] | 100% Completed |  4.1s
# 27062 finished: /gpfs/work1/0/wtrcycle/users/jaerts/model_refinement_pub/results/soil_moisture_evaluation/regridded_pcr-globwb_sm/27062_pcr-globwb_sm_2015_2017.nc
# [########################################] | 100% Completed |  2.7s
# 27064 finished: /gpfs/work1/0/wtrcycle/users/jaerts/model_refinement_pub/results/soil_moisture_evaluation/regridded_pcr-globwb_sm/27064_pcr-globwb_sm_2015_2017.nc
# [########################################] | 100% Completed |  2.7s
# 27065 finished: /gpfs/work1/0/wtrcycle/users/jaerts/model_refinement_pub/results/soil_moisture_evaluation/regridded_pcr-globwb_sm/27065_pcr-globwb_sm_2015_2017.nc
# [########################################] | 100% Completed |  5.0s
# 27071 finished: /gpfs/work1/0/wtrcycle/users/jaerts/model_refinement_pub/results/soil_moisture_evaluation/regridded_pcr-globwb_sm/27071_pcr-globwb_sm_2015_2017.nc
# [########################################] | 100% Completed |  2.7s
# 27073 finished: /gpfs/work1/0/wtrcycle/users/jaerts/model_refinement_pub/results/soil_moisture_evaluation/regridded_pcr-globwb_sm/27073_pcr-globwb_sm_2015_2017.nc
# [########################################] | 100% Completed |  2.7s
# 27077 finished: /gpfs/work1/0/wtrcycle/users/jaerts/model_refinement_pub/results/soil_moisture_evaluation/regridded_pcr-globwb_sm/27077_pcr-globwb_sm_2015_2017.nc
# [########################################] | 100% Completed |  4.4s
# 27079 finished: /gpfs/work1/0/wtrcycle/users/jaerts/model_refinement_pub/results/soil_moisture_evaluation/regridded_pcr-globwb_sm/27079_pcr-globwb_sm_2015_2017.nc
# [########################################] | 100% Completed |  4.8s
# 27080 finished: /gpfs/work1/0/wtrcycle/users/jaerts/model_refinement_pub/results/soil_moisture_evaluation/regridded_pcr-globwb_sm/27080_pcr-globwb_sm_2015_2017.nc
# [########################################] | 100% Completed |  3.2s
# 27084 finished: /gpfs/work1/0/wtrcycle/users/jaerts/model_refinement_pub/results/soil_moisture_evaluation/regridded_pcr-globwb_sm/27084_pcr-globwb_sm_2015_2017.nc
# [########################################] | 100% Completed |  4.4s
# 27087 finished: /gpfs/work1/0/wtrcycle/users/jaerts/model_refinement_pub/results/soil_moisture_evaluation/regridded_pcr-globwb_sm/27087_pcr-globwb_sm_2015_2017.nc
# [########################################] | 100% Completed |  5.5s
# 27089 finished: /gpfs/work1/0/wtrcycle/users/jaerts/model_refinement_pub/results/soil_moisture_evaluation/regridded_pcr-globwb_sm/27089_pcr-globwb_sm_2015_2017.nc
# [########################################] | 100% Completed |  3.8s
# 27090 finished: /gpfs/work1/0/wtrcycle/users/jaerts/model_refinement_pub/results/soil_moisture_evaluation/regridded_pcr-globwb_sm/27090_pcr-globwb_sm_2015_2017.nc
# [########################################] | 100% Completed |  3.8s
# 28003 finished: /gpfs/work1/0/wtrcycle/users/jaerts/model_refinement_pub/results/soil_moisture_evaluation/regridded_pcr-globwb_sm/28003_pcr-globwb_sm_2015_2017.nc
# [########################################] | 100% Completed |  3.7s
# 28008 finished: /gpfs/work1/0/wtrcycle/users/jaerts/model_refinement_pub/results/soil_moisture_evaluation/regridded_pcr-globwb_sm/28008_pcr-globwb_sm_2015_2017.nc
# [########################################] | 100% Completed | 17.2s
# 28009 finished: /gpfs/work1/0/wtrcycle/users/jaerts/model_refinement_pub/results/soil_moisture_evaluation/regridded_pcr-globwb_sm/28009_pcr-globwb_sm_2015_2017.nc
# [########################################] | 100% Completed |  5.8s
# 28012 finished: /gpfs/work1/0/wtrcycle/users/jaerts/model_refinement_pub/results/soil_moisture_evaluation/regridded_pcr-globwb_sm/28012_pcr-globwb_sm_2015_2017.nc
# [########################################] | 100% Completed |  3.7s
# 28015 finished: /gpfs/work1/0/wtrcycle/users/jaerts/model_refinement_pub/results/soil_moisture_evaluation/regridded_pcr-globwb_sm/28015_pcr-globwb_sm_2015_2017.nc
# [########################################] | 100% Completed |  4.6s
# 28018 finished: /gpfs/work1/0/wtrcycle/users/jaerts/model_refinement_pub/results/soil_moisture_evaluation/regridded_pcr-globwb_sm/28018_pcr-globwb_sm_2015_2017.nc
# [########################################] | 100% Completed | 16.8s
# 28022 finished: /gpfs/work1/0/wtrcycle/users/jaerts/model_refinement_pub/results/soil_moisture_evaluation/regridded_pcr-globwb_sm/28022_pcr-globwb_sm_2015_2017.nc
# [########################################] | 100% Completed |  3.7s
# 28023 finished: /gpfs/work1/0/wtrcycle/users/jaerts/model_refinement_pub/results/soil_moisture_evaluation/regridded_pcr-globwb_sm/28023_pcr-globwb_sm_2015_2017.nc
# [########################################] | 100% Completed |  3.6s
# 28024 finished: /gpfs/work1/0/wtrcycle/users/jaerts/model_refinement_pub/results/soil_moisture_evaluation/regridded_pcr-globwb_sm/28024_pcr-globwb_sm_2015_2017.nc
# [########################################] | 100% Completed |  3.4s
# 28026 finished: /gpfs/work1/0/wtrcycle/users/jaerts/model_refinement_pub/results/soil_moisture_evaluation/regridded_pcr-globwb_sm/28026_pcr-globwb_sm_2015_2017.nc
# [########################################] | 100% Completed |  3.4s
# 28031 finished: /gpfs/work1/0/wtrcycle/users/jaerts/model_refinement_pub/results/soil_moisture_evaluation/regridded_pcr-globwb_sm/28031_pcr-globwb_sm_2015_2017.nc
# [########################################] | 100% Completed |  3.4s
# 28033 finished: /gpfs/work1/0/wtrcycle/users/jaerts/model_refinement_pub/results/soil_moisture_evaluation/regridded_pcr-globwb_sm/28033_pcr-globwb_sm_2015_2017.nc
# [########################################] | 100% Completed |  3.5s
# 28039 finished: /gpfs/work1/0/wtrcycle/users/jaerts/model_refinement_pub/results/soil_moisture_evaluation/regridded_pcr-globwb_sm/28039_pcr-globwb_sm_2015_2017.nc
# [########################################] | 100% Completed |  3.0s
# 28040 finished: /gpfs/work1/0/wtrcycle/users/jaerts/model_refinement_pub/results/soil_moisture_evaluation/regridded_pcr-globwb_sm/28040_pcr-globwb_sm_2015_2017.nc
# [########################################] | 100% Completed |  3.7s
# 28043 finished: /gpfs/work1/0/wtrcycle/users/jaerts/model_refinement_pub/results/soil_moisture_evaluation/regridded_pcr-globwb_sm/28043_pcr-globwb_sm_2015_2017.nc
# [########################################] | 100% Completed |  3.1s
# 28044 finished: /gpfs/work1/0/wtrcycle/users/jaerts/model_refinement_pub/results/soil_moisture_evaluation/regridded_pcr-globwb_sm/28044_pcr-globwb_sm_2015_2017.nc
# [########################################] | 100% Completed |  3.4s
# 28046 finished: /gpfs/work1/0/wtrcycle/users/jaerts/model_refinement_pub/results/soil_moisture_evaluation/regridded_pcr-globwb_sm/28046_pcr-globwb_sm_2015_2017.nc
# [########################################] | 100% Completed |  3.4s
# 28048 finished: /gpfs/work1/0/wtrcycle/users/jaerts/model_refinement_pub/results/soil_moisture_evaluation/regridded_pcr-globwb_sm/28048_pcr-globwb_sm_2015_2017.nc
# [########################################] | 100% Completed |  3.5s
# 28050 finished: /gpfs/work1/0/wtrcycle/users/jaerts/model_refinement_pub/results/soil_moisture_evaluation/regridded_pcr-globwb_sm/28050_pcr-globwb_sm_2015_2017.nc
# [########################################] | 100% Completed |  3.1s
# 28052 finished: /gpfs/work1/0/wtrcycle/users/jaerts/model_refinement_pub/results/soil_moisture_evaluation/regridded_pcr-globwb_sm/28052_pcr-globwb_sm_2015_2017.nc
# [########################################] | 100% Completed |  3.4s
# 28055 finished: /gpfs/work1/0/wtrcycle/users/jaerts/model_refinement_pub/results/soil_moisture_evaluation/regridded_pcr-globwb_sm/28055_pcr-globwb_sm_2015_2017.nc
# [########################################] | 100% Completed |  3.2s
# 28056 finished: /gpfs/work1/0/wtrcycle/users/jaerts/model_refinement_pub/results/soil_moisture_evaluation/regridded_pcr-globwb_sm/28056_pcr-globwb_sm_2015_2017.nc
# [########################################] | 100% Completed |  3.0s
# 28060 finished: /gpfs/work1/0/wtrcycle/users/jaerts/model_refinement_pub/results/soil_moisture_evaluation/regridded_pcr-globwb_sm/28060_pcr-globwb_sm_2015_2017.nc
# [########################################] | 100% Completed |  3.7s
# 28066 finished: /gpfs/work1/0/wtrcycle/users/jaerts/model_refinement_pub/results/soil_moisture_evaluation/regridded_pcr-globwb_sm/28066_pcr-globwb_sm_2015_2017.nc
# [########################################] | 100% Completed |  5.8s
# 28067 finished: /gpfs/work1/0/wtrcycle/users/jaerts/model_refinement_pub/results/soil_moisture_evaluation/regridded_pcr-globwb_sm/28067_pcr-globwb_sm_2015_2017.nc
# [########################################] | 100% Completed |  3.4s
# 28072 finished: /gpfs/work1/0/wtrcycle/users/jaerts/model_refinement_pub/results/soil_moisture_evaluation/regridded_pcr-globwb_sm/28072_pcr-globwb_sm_2015_2017.nc
# [########################################] | 100% Completed |  5.0s
# 28074 finished: /gpfs/work1/0/wtrcycle/users/jaerts/model_refinement_pub/results/soil_moisture_evaluation/regridded_pcr-globwb_sm/28074_pcr-globwb_sm_2015_2017.nc
# [########################################] | 100% Completed |  4.2s
# 28080 finished: /gpfs/work1/0/wtrcycle/users/jaerts/model_refinement_pub/results/soil_moisture_evaluation/regridded_pcr-globwb_sm/28080_pcr-globwb_sm_2015_2017.nc
# [########################################] | 100% Completed |  3.3s
# 28081 finished: /gpfs/work1/0/wtrcycle/users/jaerts/model_refinement_pub/results/soil_moisture_evaluation/regridded_pcr-globwb_sm/28081_pcr-globwb_sm_2015_2017.nc
# [########################################] | 100% Completed |  3.2s
# 28082 finished: /gpfs/work1/0/wtrcycle/users/jaerts/model_refinement_pub/results/soil_moisture_evaluation/regridded_pcr-globwb_sm/28082_pcr-globwb_sm_2015_2017.nc
# [########################################] | 100% Completed |  5.7s
# 28085 finished: /gpfs/work1/0/wtrcycle/users/jaerts/model_refinement_pub/results/soil_moisture_evaluation/regridded_pcr-globwb_sm/28085_pcr-globwb_sm_2015_2017.nc
# [########################################] | 100% Completed |  3.9s
# 28091 finished: /gpfs/work1/0/wtrcycle/users/jaerts/model_refinement_pub/results/soil_moisture_evaluation/regridded_pcr-globwb_sm/28091_pcr-globwb_sm_2015_2017.nc
# [########################################] | 100% Completed |  4.7s
# 28093 finished: /gpfs/work1/0/wtrcycle/users/jaerts/model_refinement_pub/results/soil_moisture_evaluation/regridded_pcr-globwb_sm/28093_pcr-globwb_sm_2015_2017.nc
# [########################################] | 100% Completed |  3.4s
# 28115 finished: /gpfs/work1/0/wtrcycle/users/jaerts/model_refinement_pub/results/soil_moisture_evaluation/regridded_pcr-globwb_sm/28115_pcr-globwb_sm_2015_2017.nc
# [########################################] | 100% Completed |  3.4s
# 28116 finished: /gpfs/work1/0/wtrcycle/users/jaerts/model_refinement_pub/results/soil_moisture_evaluation/regridded_pcr-globwb_sm/28116_pcr-globwb_sm_2015_2017.nc
# [########################################] | 100% Completed |  4.1s
# 28117 finished: /gpfs/work1/0/wtrcycle/users/jaerts/model_refinement_pub/results/soil_moisture_evaluation/regridded_pcr-globwb_sm/28117_pcr-globwb_sm_2015_2017.nc
# [########################################] | 100% Completed |  3.0s
# 29002 finished: /gpfs/work1/0/wtrcycle/users/jaerts/model_refinement_pub/results/soil_moisture_evaluation/regridded_pcr-globwb_sm/29002_pcr-globwb_sm_2015_2017.nc
# [########################################] | 100% Completed |  3.0s
# 29003 finished: /gpfs/work1/0/wtrcycle/users/jaerts/model_refinement_pub/results/soil_moisture_evaluation/regridded_pcr-globwb_sm/29003_pcr-globwb_sm_2015_2017.nc
# [########################################] | 100% Completed |  3.4s
# 29005 finished: /gpfs/work1/0/wtrcycle/users/jaerts/model_refinement_pub/results/soil_moisture_evaluation/regridded_pcr-globwb_sm/29005_pcr-globwb_sm_2015_2017.nc
# [########################################] | 100% Completed |  3.3s
# 29009 finished: /gpfs/work1/0/wtrcycle/users/jaerts/model_refinement_pub/results/soil_moisture_evaluation/regridded_pcr-globwb_sm/29009_pcr-globwb_sm_2015_2017.nc
# [########################################] | 100% Completed |  3.6s
# 30001 finished: /gpfs/work1/0/wtrcycle/users/jaerts/model_refinement_pub/results/soil_moisture_evaluation/regridded_pcr-globwb_sm/30001_pcr-globwb_sm_2015_2017.nc
# [########################################] | 100% Completed |  3.4s
# 30004 finished: /gpfs/work1/0/wtrcycle/users/jaerts/model_refinement_pub/results/soil_moisture_evaluation/regridded_pcr-globwb_sm/30004_pcr-globwb_sm_2015_2017.nc
# [########################################] | 100% Completed |  3.3s
# 30005 finished: /gpfs/work1/0/wtrcycle/users/jaerts/model_refinement_pub/results/soil_moisture_evaluation/regridded_pcr-globwb_sm/30005_pcr-globwb_sm_2015_2017.nc
# [########################################] | 100% Completed |  3.1s
# 30011 finished: /gpfs/work1/0/wtrcycle/users/jaerts/model_refinement_pub/results/soil_moisture_evaluation/regridded_pcr-globwb_sm/30011_pcr-globwb_sm_2015_2017.nc
# [########################################] | 100% Completed |  3.4s
# 30012 finished: /gpfs/work1/0/wtrcycle/users/jaerts/model_refinement_pub/results/soil_moisture_evaluation/regridded_pcr-globwb_sm/30012_pcr-globwb_sm_2015_2017.nc
# [########################################] | 100% Completed |  3.3s
# 30014 finished: /gpfs/work1/0/wtrcycle/users/jaerts/model_refinement_pub/results/soil_moisture_evaluation/regridded_pcr-globwb_sm/30014_pcr-globwb_sm_2015_2017.nc
# [########################################] | 100% Completed |  3.2s
# 30015 finished: /gpfs/work1/0/wtrcycle/users/jaerts/model_refinement_pub/results/soil_moisture_evaluation/regridded_pcr-globwb_sm/30015_pcr-globwb_sm_2015_2017.nc
# [########################################] | 100% Completed |  3.9s
# 3003 finished: /gpfs/work1/0/wtrcycle/users/jaerts/model_refinement_pub/results/soil_moisture_evaluation/regridded_pcr-globwb_sm/3003_pcr-globwb_sm_2015_2017.nc
# [########################################] | 100% Completed |  4.4s
# 31002 finished: /gpfs/work1/0/wtrcycle/users/jaerts/model_refinement_pub/results/soil_moisture_evaluation/regridded_pcr-globwb_sm/31002_pcr-globwb_sm_2015_2017.nc
# [########################################] | 100% Completed |  4.1s
# 31006 finished: /gpfs/work1/0/wtrcycle/users/jaerts/model_refinement_pub/results/soil_moisture_evaluation/regridded_pcr-globwb_sm/31006_pcr-globwb_sm_2015_2017.nc
# [########################################] | 100% Completed |  3.9s
# 31021 finished: /gpfs/work1/0/wtrcycle/users/jaerts/model_refinement_pub/results/soil_moisture_evaluation/regridded_pcr-globwb_sm/31021_pcr-globwb_sm_2015_2017.nc
# [########################################] | 100% Completed |  2.9s
# 31023 finished: /gpfs/work1/0/wtrcycle/users/jaerts/model_refinement_pub/results/soil_moisture_evaluation/regridded_pcr-globwb_sm/31023_pcr-globwb_sm_2015_2017.nc
# [########################################] | 100% Completed |  2.9s
# 31025 finished: /gpfs/work1/0/wtrcycle/users/jaerts/model_refinement_pub/results/soil_moisture_evaluation/regridded_pcr-globwb_sm/31025_pcr-globwb_sm_2015_2017.nc
# [########################################] | 100% Completed |  3.5s
# 32003 finished: /gpfs/work1/0/wtrcycle/users/jaerts/model_refinement_pub/results/soil_moisture_evaluation/regridded_pcr-globwb_sm/32003_pcr-globwb_sm_2015_2017.nc
# [########################################] | 100% Completed |  3.6s
# 32004 finished: /gpfs/work1/0/wtrcycle/users/jaerts/model_refinement_pub/results/soil_moisture_evaluation/regridded_pcr-globwb_sm/32004_pcr-globwb_sm_2015_2017.nc
# [########################################] | 100% Completed |  3.5s
# 32006 finished: /gpfs/work1/0/wtrcycle/users/jaerts/model_refinement_pub/results/soil_moisture_evaluation/regridded_pcr-globwb_sm/32006_pcr-globwb_sm_2015_2017.nc
# [########################################] | 100% Completed |  3.0s
# 32008 finished: /gpfs/work1/0/wtrcycle/users/jaerts/model_refinement_pub/results/soil_moisture_evaluation/regridded_pcr-globwb_sm/32008_pcr-globwb_sm_2015_2017.nc
# [########################################] | 100% Completed |  3.6s
# 33006 finished: /gpfs/work1/0/wtrcycle/users/jaerts/model_refinement_pub/results/soil_moisture_evaluation/regridded_pcr-globwb_sm/33006_pcr-globwb_sm_2015_2017.nc
# [########################################] | 100% Completed |  3.7s
# 33007 finished: /gpfs/work1/0/wtrcycle/users/jaerts/model_refinement_pub/results/soil_moisture_evaluation/regridded_pcr-globwb_sm/33007_pcr-globwb_sm_2015_2017.nc
# [########################################] | 100% Completed |  3.4s
# 33012 finished: /gpfs/work1/0/wtrcycle/users/jaerts/model_refinement_pub/results/soil_moisture_evaluation/regridded_pcr-globwb_sm/33012_pcr-globwb_sm_2015_2017.nc
# [########################################] | 100% Completed |  3.5s
# 33013 finished: /gpfs/work1/0/wtrcycle/users/jaerts/model_refinement_pub/results/soil_moisture_evaluation/regridded_pcr-globwb_sm/33013_pcr-globwb_sm_2015_2017.nc
# [########################################] | 100% Completed |  3.4s
# 33014 finished: /gpfs/work1/0/wtrcycle/users/jaerts/model_refinement_pub/results/soil_moisture_evaluation/regridded_pcr-globwb_sm/33014_pcr-globwb_sm_2015_2017.nc
# [########################################] | 100% Completed |  3.5s
# 33018 finished: /gpfs/work1/0/wtrcycle/users/jaerts/model_refinement_pub/results/soil_moisture_evaluation/regridded_pcr-globwb_sm/33018_pcr-globwb_sm_2015_2017.nc
# [########################################] | 100% Completed |  3.7s
# 33019 finished: /gpfs/work1/0/wtrcycle/users/jaerts/model_refinement_pub/results/soil_moisture_evaluation/regridded_pcr-globwb_sm/33019_pcr-globwb_sm_2015_2017.nc
# [########################################] | 100% Completed |  3.5s
# 33020 finished: /gpfs/work1/0/wtrcycle/users/jaerts/model_refinement_pub/results/soil_moisture_evaluation/regridded_pcr-globwb_sm/33020_pcr-globwb_sm_2015_2017.nc
# [########################################] | 100% Completed |  3.4s
# 33021 finished: /gpfs/work1/0/wtrcycle/users/jaerts/model_refinement_pub/results/soil_moisture_evaluation/regridded_pcr-globwb_sm/33021_pcr-globwb_sm_2015_2017.nc
# [########################################] | 100% Completed |  4.0s
# ...
# [########################################] | 100% Completed |  3.6s
# 77004 finished: /gpfs/work1/0/wtrcycle/users/jaerts/model_refinement_pub/results/soil_moisture_evaluation/regridded_pcr-globwb_sm/77004_pcr-globwb_sm_2015_2017.nc
# [########################################] | 100% Completed |  5.0s
# 78003 finished: /gpfs/work1/0/wtrcycle/users/jaerts/model_refinement_pub/results/soil_moisture_evaluation/regridded_pcr-globwb_sm/78003_pcr-globwb_sm_2015_2017.nc
# [########################################] | 100% Completed |  3.5s
# 78004 finished: /gpfs/work1/0/wtrcycle/users/jaerts/model_refinement_pub/results/soil_moisture_evaluation/regridded_pcr-globwb_sm/78004_pcr-globwb_sm_2015_2017.nc
# [########################################] | 100% Completed |  3.4s
# 78006 finished: /gpfs/work1/0/wtrcycle/users/jaerts/model_refinement_pub/results/soil_moisture_evaluation/regridded_pcr-globwb_sm/78006_pcr-globwb_sm_2015_2017.nc
# [########################################] | 100% Completed |  4.4s
# 79002 finished: /gpfs/work1/0/wtrcycle/users/jaerts/model_refinement_pub/results/soil_moisture_evaluation/regridded_pcr-globwb_sm/79002_pcr-globwb_sm_2015_2017.nc
# [########################################] | 100% Completed |  3.7s
# 79003 finished: /gpfs/work1/0/wtrcycle/users/jaerts/model_refinement_pub/results/soil_moisture_evaluation/regridded_pcr-globwb_sm/79003_pcr-globwb_sm_2015_2017.nc
# [########################################] | 100% Completed |  3.4s
# 79004 finished: /gpfs/work1/0/wtrcycle/users/jaerts/model_refinement_pub/results/soil_moisture_evaluation/regridded_pcr-globwb_sm/79004_pcr-globwb_sm_2015_2017.nc
# [########################################] | 100% Completed |  3.7s
# 79005 finished: /gpfs/work1/0/wtrcycle/users/jaerts/model_refinement_pub/results/soil_moisture_evaluation/regridded_pcr-globwb_sm/79005_pcr-globwb_sm_2015_2017.nc
# [########################################] | 100% Completed |  4.1s
# 79006 finished: /gpfs/work1/0/wtrcycle/users/jaerts/model_refinement_pub/results/soil_moisture_evaluation/regridded_pcr-globwb_sm/79006_pcr-globwb_sm_2015_2017.nc
# [########################################] | 100% Completed |  3.4s
# 80001 finished: /gpfs/work1/0/wtrcycle/users/jaerts/model_refinement_pub/results/soil_moisture_evaluation/regridded_pcr-globwb_sm/80001_pcr-globwb_sm_2015_2017.nc
# [########################################] | 100% Completed |  3.2s
# 80003 finished: /gpfs/work1/0/wtrcycle/users/jaerts/model_refinement_pub/results/soil_moisture_evaluation/regridded_pcr-globwb_sm/80003_pcr-globwb_sm_2015_2017.nc
# [########################################] | 100% Completed |  3.1s
# 80004 finished: /gpfs/work1/0/wtrcycle/users/jaerts/model_refinement_pub/results/soil_moisture_evaluation/regridded_pcr-globwb_sm/80004_pcr-globwb_sm_2015_2017.nc
# [########################################] | 100% Completed |  3.5s
# 80005 finished: /gpfs/work1/0/wtrcycle/users/jaerts/model_refinement_pub/results/soil_moisture_evaluation/regridded_pcr-globwb_sm/80005_pcr-globwb_sm_2015_2017.nc
# [########################################] | 100% Completed |  3.1s
# 80006 finished: /gpfs/work1/0/wtrcycle/users/jaerts/model_refinement_pub/results/soil_moisture_evaluation/regridded_pcr-globwb_sm/80006_pcr-globwb_sm_2015_2017.nc
# [########################################] | 100% Completed |  4.1s
# 8004 finished: /gpfs/work1/0/wtrcycle/users/jaerts/model_refinement_pub/results/soil_moisture_evaluation/regridded_pcr-globwb_sm/8004_pcr-globwb_sm_2015_2017.nc
# [########################################] | 100% Completed |  6.2s
# 8005 finished: /gpfs/work1/0/wtrcycle/users/jaerts/model_refinement_pub/results/soil_moisture_evaluation/regridded_pcr-globwb_sm/8005_pcr-globwb_sm_2015_2017.nc
# [########################################] | 100% Completed | 11.3s
# 8006 finished: /gpfs/work1/0/wtrcycle/users/jaerts/model_refinement_pub/results/soil_moisture_evaluation/regridded_pcr-globwb_sm/8006_pcr-globwb_sm_2015_2017.nc
# [########################################] | 100% Completed |  3.9s
# 8009 finished: /gpfs/work1/0/wtrcycle/users/jaerts/model_refinement_pub/results/soil_moisture_evaluation/regridded_pcr-globwb_sm/8009_pcr-globwb_sm_2015_2017.nc
# [########################################] | 100% Completed |  3.4s
# 8011 finished: /gpfs/work1/0/wtrcycle/users/jaerts/model_refinement_pub/results/soil_moisture_evaluation/regridded_pcr-globwb_sm/8011_pcr-globwb_sm_2015_2017.nc
# [########################################] | 100% Completed |  3.5s
# 8013 finished: /gpfs/work1/0/wtrcycle/users/jaerts/model_refinement_pub/results/soil_moisture_evaluation/regridded_pcr-globwb_sm/8013_pcr-globwb_sm_2015_2017.nc
# [########################################] | 100% Completed |  3.9s
# 81002 finished: /gpfs/work1/0/wtrcycle/users/jaerts/model_refinement_pub/results/soil_moisture_evaluation/regridded_pcr-globwb_sm/81002_pcr-globwb_sm_2015_2017.nc
# [########################################] | 100% Completed |  3.3s
# 81003 finished: /gpfs/work1/0/wtrcycle/users/jaerts/model_refinement_pub/results/soil_moisture_evaluation/regridded_pcr-globwb_sm/81003_pcr-globwb_sm_2015_2017.nc
# [########################################] | 100% Completed |  3.9s
# 81004 finished: /gpfs/work1/0/wtrcycle/users/jaerts/model_refinement_pub/results/soil_moisture_evaluation/regridded_pcr-globwb_sm/81004_pcr-globwb_sm_2015_2017.nc
# [########################################] | 100% Completed |  3.7s
# 81006 finished: /gpfs/work1/0/wtrcycle/users/jaerts/model_refinement_pub/results/soil_moisture_evaluation/regridded_pcr-globwb_sm/81006_pcr-globwb_sm_2015_2017.nc
# [########################################] | 100% Completed |  3.2s
# 81007 finished: /gpfs/work1/0/wtrcycle/users/jaerts/model_refinement_pub/results/soil_moisture_evaluation/regridded_pcr-globwb_sm/81007_pcr-globwb_sm_2015_2017.nc
# [########################################] | 100% Completed |  3.5s
# 82001 finished: /gpfs/work1/0/wtrcycle/users/jaerts/model_refinement_pub/results/soil_moisture_evaluation/regridded_pcr-globwb_sm/82001_pcr-globwb_sm_2015_2017.nc
# [########################################] | 100% Completed |  3.5s
# 82003 finished: /gpfs/work1/0/wtrcycle/users/jaerts/model_refinement_pub/results/soil_moisture_evaluation/regridded_pcr-globwb_sm/82003_pcr-globwb_sm_2015_2017.nc
# [########################################] | 100% Completed |  3.3s
# 83003 finished: /gpfs/work1/0/wtrcycle/users/jaerts/model_refinement_pub/results/soil_moisture_evaluation/regridded_pcr-globwb_sm/83003_pcr-globwb_sm_2015_2017.nc
# [########################################] | 100% Completed |  3.3s
# 83004 finished: /gpfs/work1/0/wtrcycle/users/jaerts/model_refinement_pub/results/soil_moisture_evaluation/regridded_pcr-globwb_sm/83004_pcr-globwb_sm_2015_2017.nc
# [########################################] | 100% Completed |  4.0s
# 83006 finished: /gpfs/work1/0/wtrcycle/users/jaerts/model_refinement_pub/results/soil_moisture_evaluation/regridded_pcr-globwb_sm/83006_pcr-globwb_sm_2015_2017.nc
# [########################################] | 100% Completed |  3.5s
# 83007 finished: /gpfs/work1/0/wtrcycle/users/jaerts/model_refinement_pub/results/soil_moisture_evaluation/regridded_pcr-globwb_sm/83007_pcr-globwb_sm_2015_2017.nc
# [########################################] | 100% Completed |  3.3s
# 83009 finished: /gpfs/work1/0/wtrcycle/users/jaerts/model_refinement_pub/results/soil_moisture_evaluation/regridded_pcr-globwb_sm/83009_pcr-globwb_sm_2015_2017.nc
# [########################################] | 100% Completed |  3.3s
# 83010 finished: /gpfs/work1/0/wtrcycle/users/jaerts/model_refinement_pub/results/soil_moisture_evaluation/regridded_pcr-globwb_sm/83010_pcr-globwb_sm_2015_2017.nc
# [########################################] | 100% Completed |  3.6s
# 83013 finished: /gpfs/work1/0/wtrcycle/users/jaerts/model_refinement_pub/results/soil_moisture_evaluation/regridded_pcr-globwb_sm/83013_pcr-globwb_sm_2015_2017.nc
# [########################################] | 100% Completed |  4.1s
# 84001 finished: /gpfs/work1/0/wtrcycle/users/jaerts/model_refinement_pub/results/soil_moisture_evaluation/regridded_pcr-globwb_sm/84001_pcr-globwb_sm_2015_2017.nc
# [########################################] | 100% Completed |  5.2s
# 84004 finished: /gpfs/work1/0/wtrcycle/users/jaerts/model_refinement_pub/results/soil_moisture_evaluation/regridded_pcr-globwb_sm/84004_pcr-globwb_sm_2015_2017.nc
# [########################################] | 100% Completed |  6.7s
# 84005 finished: /gpfs/work1/0/wtrcycle/users/jaerts/model_refinement_pub/results/soil_moisture_evaluation/regridded_pcr-globwb_sm/84005_pcr-globwb_sm_2015_2017.nc
# [########################################] | 100% Completed |  7.0s
# 84008 finished: /gpfs/work1/0/wtrcycle/users/jaerts/model_refinement_pub/results/soil_moisture_evaluation/regridded_pcr-globwb_sm/84008_pcr-globwb_sm_2015_2017.nc
# [########################################] | 100% Completed |  3.5s
# 84009 finished: /gpfs/work1/0/wtrcycle/users/jaerts/model_refinement_pub/results/soil_moisture_evaluation/regridded_pcr-globwb_sm/84009_pcr-globwb_sm_2015_2017.nc
# [########################################] | 100% Completed |  3.8s
# 84012 finished: /gpfs/work1/0/wtrcycle/users/jaerts/model_refinement_pub/results/soil_moisture_evaluation/regridded_pcr-globwb_sm/84012_pcr-globwb_sm_2015_2017.nc
# [########################################] | 100% Completed |  6.8s
# 84013 finished: /gpfs/work1/0/wtrcycle/users/jaerts/model_refinement_pub/results/soil_moisture_evaluation/regridded_pcr-globwb_sm/84013_pcr-globwb_sm_2015_2017.nc
# [########################################] | 100% Completed |  4.1s
# 84014 finished: /gpfs/work1/0/wtrcycle/users/jaerts/model_refinement_pub/results/soil_moisture_evaluation/regridded_pcr-globwb_sm/84014_pcr-globwb_sm_2015_2017.nc
# [########################################] | 100% Completed |  3.1s
# 84016 finished: /gpfs/work1/0/wtrcycle/users/jaerts/model_refinement_pub/results/soil_moisture_evaluation/regridded_pcr-globwb_sm/84016_pcr-globwb_sm_2015_2017.nc
# [########################################] | 100% Completed |  3.4s
# 84017 finished: /gpfs/work1/0/wtrcycle/users/jaerts/model_refinement_pub/results/soil_moisture_evaluation/regridded_pcr-globwb_sm/84017_pcr-globwb_sm_2015_2017.nc
# [########################################] | 100% Completed |  6.3s
# 84019 finished: /gpfs/work1/0/wtrcycle/users/jaerts/model_refinement_pub/results/soil_moisture_evaluation/regridded_pcr-globwb_sm/84019_pcr-globwb_sm_2015_2017.nc
# [########################################] | 100% Completed |  3.5s
# 84020 finished: /gpfs/work1/0/wtrcycle/users/jaerts/model_refinement_pub/results/soil_moisture_evaluation/regridded_pcr-globwb_sm/84020_pcr-globwb_sm_2015_2017.nc
# [########################################] | 100% Completed |  3.9s
# 84022 finished: /gpfs/work1/0/wtrcycle/users/jaerts/model_refinement_pub/results/soil_moisture_evaluation/regridded_pcr-globwb_sm/84022_pcr-globwb_sm_2015_2017.nc
# [########################################] | 100% Completed |  3.0s
# 84026 finished: /gpfs/work1/0/wtrcycle/users/jaerts/model_refinement_pub/results/soil_moisture_evaluation/regridded_pcr-globwb_sm/84026_pcr-globwb_sm_2015_2017.nc
# [########################################] | 100% Completed |  3.4s
# 84030 finished: /gpfs/work1/0/wtrcycle/users/jaerts/model_refinement_pub/results/soil_moisture_evaluation/regridded_pcr-globwb_sm/84030_pcr-globwb_sm_2015_2017.nc
# [########################################] | 100% Completed |  5.5s
# 85001 finished: /gpfs/work1/0/wtrcycle/users/jaerts/model_refinement_pub/results/soil_moisture_evaluation/regridded_pcr-globwb_sm/85001_pcr-globwb_sm_2015_2017.nc
# [########################################] | 100% Completed |  3.9s
# 85002 finished: /gpfs/work1/0/wtrcycle/users/jaerts/model_refinement_pub/results/soil_moisture_evaluation/regridded_pcr-globwb_sm/85002_pcr-globwb_sm_2015_2017.nc
# [########################################] | 100% Completed |  3.2s
# 85003 finished: /gpfs/work1/0/wtrcycle/users/jaerts/model_refinement_pub/results/soil_moisture_evaluation/regridded_pcr-globwb_sm/85003_pcr-globwb_sm_2015_2017.nc
# [########################################] | 100% Completed |  3.7s
# 85004 finished: /gpfs/work1/0/wtrcycle/users/jaerts/model_refinement_pub/results/soil_moisture_evaluation/regridded_pcr-globwb_sm/85004_pcr-globwb_sm_2015_2017.nc
# [########################################] | 100% Completed |  3.5s
# 88001 finished: /gpfs/work1/0/wtrcycle/users/jaerts/model_refinement_pub/results/soil_moisture_evaluation/regridded_pcr-globwb_sm/88001_pcr-globwb_sm_2015_2017.nc
# [########################################] | 100% Completed |  3.5s
# 89002 finished: /gpfs/work1/0/wtrcycle/users/jaerts/model_refinement_pub/results/soil_moisture_evaluation/regridded_pcr-globwb_sm/89002_pcr-globwb_sm_2015_2017.nc
# [########################################] | 100% Completed |  3.5s
# 89005 finished: /gpfs/work1/0/wtrcycle/users/jaerts/model_refinement_pub/results/soil_moisture_evaluation/regridded_pcr-globwb_sm/89005_pcr-globwb_sm_2015_2017.nc
# [########################################] | 100% Completed |  3.9s
# 90003 finished: /gpfs/work1/0/wtrcycle/users/jaerts/model_refinement_pub/results/soil_moisture_evaluation/regridded_pcr-globwb_sm/90003_pcr-globwb_sm_2015_2017.nc
# [########################################] | 100% Completed |  5.1s
# 9002 finished: /gpfs/work1/0/wtrcycle/users/jaerts/model_refinement_pub/results/soil_moisture_evaluation/regridded_pcr-globwb_sm/9002_pcr-globwb_sm_2015_2017.nc
# [########################################] | 100% Completed |  4.4s
# 9003 finished: /gpfs/work1/0/wtrcycle/users/jaerts/model_refinement_pub/results/soil_moisture_evaluation/regridded_pcr-globwb_sm/9003_pcr-globwb_sm_2015_2017.nc
# [########################################] | 100% Completed |  3.4s
# 9004 finished: /gpfs/work1/0/wtrcycle/users/jaerts/model_refinement_pub/results/soil_moisture_evaluation/regridded_pcr-globwb_sm/9004_pcr-globwb_sm_2015_2017.nc
# [########################################] | 100% Completed |  3.6s
# 9005 finished: /gpfs/work1/0/wtrcycle/users/jaerts/model_refinement_pub/results/soil_moisture_evaluation/regridded_pcr-globwb_sm/9005_pcr-globwb_sm_2015_2017.nc
# [########################################] | 100% Completed |  3.7s
# 92001 finished: /gpfs/work1/0/wtrcycle/users/jaerts/model_refinement_pub/results/soil_moisture_evaluation/regridded_pcr-globwb_sm/92001_pcr-globwb_sm_2015_2017.nc
# [########################################] | 100% Completed |  3.7s
# 93001 finished: /gpfs/work1/0/wtrcycle/users/jaerts/model_refinement_pub/results/soil_moisture_evaluation/regridded_pcr-globwb_sm/93001_pcr-globwb_sm_2015_2017.nc
# [########################################] | 100% Completed |  4.2s
# 94001 finished: /gpfs/work1/0/wtrcycle/users/jaerts/model_refinement_pub/results/soil_moisture_evaluation/regridded_pcr-globwb_sm/94001_pcr-globwb_sm_2015_2017.nc
# [########################################] | 100% Completed |  3.5s
# 95001 finished: /gpfs/work1/0/wtrcycle/users/jaerts/model_refinement_pub/results/soil_moisture_evaluation/regridded_pcr-globwb_sm/95001_pcr-globwb_sm_2015_2017.nc
# [########################################] | 100% Completed |  3.2s
# 96001 finished: /gpfs/work1/0/wtrcycle/users/jaerts/model_refinement_pub/results/soil_moisture_evaluation/regridded_pcr-globwb_sm/96001_pcr-globwb_sm_2015_2017.nc
# [########################################] | 100% Completed |  4.3s
# 96002 finished: /gpfs/work1/0/wtrcycle/users/jaerts/model_refinement_pub/results/soil_moisture_evaluation/regridded_pcr-globwb_sm/96002_pcr-globwb_sm_2015_2017.nc
# [########################################] | 100% Completed |  3.6s
# 96004 finished: /gpfs/work1/0/wtrcycle/users/jaerts/model_refinement_pub/results/soil_moisture_evaluation/regridded_pcr-globwb_sm/96004_pcr-globwb_sm_2015_2017.nc
# [########################################] | 100% Completed |  4.1s
# 97002 finished: /gpfs/work1/0/wtrcycle/users/jaerts/model_refinement_pub/results/soil_moisture_evaluation/regridded_pcr-globwb_sm/97002_pcr-globwb_sm_2015_2017.nc

# %% [markdown]
# ## Post-process pcr-globwb evaporation output (totalEvaporation)

# %%
def post_et_output(basin_id):
    # Set basin directory
    BASINDIR = f'{MODELS}/wflow_sbm/{basin_id}/'

    # Open netCDF file as an example grid from the model directory
    cube_example = iris.load(f'{BASINDIR}/staticmaps.nc')[1]

    # Guess bounds   
    cube_example.coord('y').guess_bounds()
    cube_example.coord('x').guess_bounds()

    # Rename Coords
    cube_example.coord('y').rename('latitude')
    cube_example.coord('x').rename('longitude')

    cube_example.coord('latitude').units = 'degrees'
    cube_example.coord('longitude').units = 'degrees'

    # Load output netCDF files
    evap_file = f'{MODELS}/pcr-globwb/uk_spinup_traveltime/netcdf/totalEvaporation_dailyTot_output.nc'
    
    # Load output
    cube_sim = iris.load(evap_file)[0]

    # Guess bounds   
    cube_sim.coord('latitude').guess_bounds()
    cube_sim.coord('longitude').guess_bounds()

    # Regrid observation cube
    cube_out = regrid(cube_sim, cube_example, scheme='area_weighted')

    # Create obs dataset
    da = xr.DataArray.from_iris(cube_out)

    # Create mask dataset
    mask = xr.open_dataset(f'{BASINDIR}/staticmaps.nc').mask
    mask = mask.rename({'y':'latitude','x':'longitude'})

    # Apply mask
    da = da.where(mask>0)

    # Calculate time series
    da = da.mean(['latitude','longitude'])
    da = da.chunk(chunks='auto')
    da = da.drop('spatial_ref')

    # Convert m to mm
    da = da* 1000

    # Select time series that matches ref obs
    da = da.sel(time=slice('2008','2015'))

    # Resample to 8 daily interval per year
    sim_years = []
    years = da.resample(time='Y').mean().time.dt.year
    for year in years.values:
        ds_sim_year = da.sel(time=str(year))
        sim_years.append(ds_sim_year.resample(time='8D').mean())

    da = xr.concat(sim_years, dim='time')
    
    # Output filename
    output_fname = f'{OUTPUT}/evaporation_evaluation/regridded_pcr-globwb_evaporation/{basin_id}_pcr-globwb_et_2008_2015.nc'

    # Save to netcdf
    write_job = da.to_netcdf(output_fname, compute=False)
    with ProgressBar():
        write_job.compute()
        
    return print(f'{basin_id} finished: {output_fname}')
    # return da

# %% [markdown]
# ## Parallel run function

# %%
def parallel_run_et(
    basin_ids,
    threads=cores_available,
    ):
    
    # Set number of threads (cores) used for parallel run and map threads
    if threads is None:
        pool = Pool()
    else:
        pool = Pool(nodes=threads)
    # Run parallel models
    pool.map(
        post_et_output,
        basin_ids,
        )
    return

# %% [markdown]
# ## Sort basins by size

# %%
# Sort by basin size
def sort_basin_ids_by_size(basin_ids):
    sizes = []
    for basin_id in basin_ids:
        size = os.path.getsize(f'{MODELS}/wflow_sbm/{basin_id}/staticmaps.nc')
        sizes.append(size)

    df = pd.DataFrame()
    df['basin_id'] = basin_ids
    df['size'] = sizes
    df = df.sort_values('size')

    basin_ids = df.basin_id.to_list()
    
    return basin_ids

basin_ids_sorted = sort_basin_ids_by_size(basin_ids)

# %% [markdown]
# ## Run parallel function

# %%
# Run function
# parallel_run_et(basin_ids_sorted)
parallel_run_et(basin_ids)
# Out:
# [########################################] | 100% Completed |  5.3s
# 10003 finished: /gpfs/work1/0/wtrcycle/users/jaerts/model_refinement_pub/results/evaporation_evaluation/regridded_pcr-globwb_evaporation/10003_pcr-globwb_et_2008_2015.nc
# [########################################] | 100% Completed |  4.3s
# 1001 finished: /gpfs/work1/0/wtrcycle/users/jaerts/model_refinement_pub/results/evaporation_evaluation/regridded_pcr-globwb_evaporation/1001_pcr-globwb_et_2008_2015.nc
# [########################################] | 100% Completed |  4.3s
# 101002 finished: /gpfs/work1/0/wtrcycle/users/jaerts/model_refinement_pub/results/evaporation_evaluation/regridded_pcr-globwb_evaporation/101002_pcr-globwb_et_2008_2015.nc
# [########################################] | 100% Completed |  4.2s
# 101005 finished: /gpfs/work1/0/wtrcycle/users/jaerts/model_refinement_pub/results/evaporation_evaluation/regridded_pcr-globwb_evaporation/101005_pcr-globwb_et_2008_2015.nc
# [########################################] | 100% Completed |  4.3s
# 102001 finished: /gpfs/work1/0/wtrcycle/users/jaerts/model_refinement_pub/results/evaporation_evaluation/regridded_pcr-globwb_evaporation/102001_pcr-globwb_et_2008_2015.nc
# [########################################] | 100% Completed |  4.4s
# 106001 finished: /gpfs/work1/0/wtrcycle/users/jaerts/model_refinement_pub/results/evaporation_evaluation/regridded_pcr-globwb_evaporation/106001_pcr-globwb_et_2008_2015.nc
# [########################################] | 100% Completed |  4.4s
# 107001 finished: /gpfs/work1/0/wtrcycle/users/jaerts/model_refinement_pub/results/evaporation_evaluation/regridded_pcr-globwb_evaporation/107001_pcr-globwb_et_2008_2015.nc
# [########################################] | 100% Completed |  6.3s
# 11001 finished: /gpfs/work1/0/wtrcycle/users/jaerts/model_refinement_pub/results/evaporation_evaluation/regridded_pcr-globwb_evaporation/11001_pcr-globwb_et_2008_2015.nc
# [########################################] | 100% Completed |  5.0s
# 11003 finished: /gpfs/work1/0/wtrcycle/users/jaerts/model_refinement_pub/results/evaporation_evaluation/regridded_pcr-globwb_evaporation/11003_pcr-globwb_et_2008_2015.nc
# [########################################] | 100% Completed |  4.5s
# 11004 finished: /gpfs/work1/0/wtrcycle/users/jaerts/model_refinement_pub/results/evaporation_evaluation/regridded_pcr-globwb_evaporation/11004_pcr-globwb_et_2008_2015.nc
# [########################################] | 100% Completed |  6.3s
# 12001 finished: /gpfs/work1/0/wtrcycle/users/jaerts/model_refinement_pub/results/evaporation_evaluation/regridded_pcr-globwb_evaporation/12001_pcr-globwb_et_2008_2015.nc
# [########################################] | 100% Completed |  6.7s
# 12002 finished: /gpfs/work1/0/wtrcycle/users/jaerts/model_refinement_pub/results/evaporation_evaluation/regridded_pcr-globwb_evaporation/12002_pcr-globwb_et_2008_2015.nc
# [########################################] | 100% Completed |  4.5s
# 12005 finished: /gpfs/work1/0/wtrcycle/users/jaerts/model_refinement_pub/results/evaporation_evaluation/regridded_pcr-globwb_evaporation/12005_pcr-globwb_et_2008_2015.nc
# [########################################] | 100% Completed |  4.4s
# 12006 finished: /gpfs/work1/0/wtrcycle/users/jaerts/model_refinement_pub/results/evaporation_evaluation/regridded_pcr-globwb_evaporation/12006_pcr-globwb_et_2008_2015.nc
# [########################################] | 100% Completed |  4.6s
# 12007 finished: /gpfs/work1/0/wtrcycle/users/jaerts/model_refinement_pub/results/evaporation_evaluation/regridded_pcr-globwb_evaporation/12007_pcr-globwb_et_2008_2015.nc
# [########################################] | 100% Completed |  4.5s
# 12008 finished: /gpfs/work1/0/wtrcycle/users/jaerts/model_refinement_pub/results/evaporation_evaluation/regridded_pcr-globwb_evaporation/12008_pcr-globwb_et_2008_2015.nc
# [########################################] | 100% Completed |  4.1s
# 12009 finished: /gpfs/work1/0/wtrcycle/users/jaerts/model_refinement_pub/results/evaporation_evaluation/regridded_pcr-globwb_evaporation/12009_pcr-globwb_et_2008_2015.nc
# [########################################] | 100% Completed |  4.6s
# 13001 finished: /gpfs/work1/0/wtrcycle/users/jaerts/model_refinement_pub/results/evaporation_evaluation/regridded_pcr-globwb_evaporation/13001_pcr-globwb_et_2008_2015.nc
# [########################################] | 100% Completed |  4.5s
# 13004 finished: /gpfs/work1/0/wtrcycle/users/jaerts/model_refinement_pub/results/evaporation_evaluation/regridded_pcr-globwb_evaporation/13004_pcr-globwb_et_2008_2015.nc
# [########################################] | 100% Completed |  4.5s
# 13005 finished: /gpfs/work1/0/wtrcycle/users/jaerts/model_refinement_pub/results/evaporation_evaluation/regridded_pcr-globwb_evaporation/13005_pcr-globwb_et_2008_2015.nc
# [########################################] | 100% Completed |  5.3s
# 13007 finished: /gpfs/work1/0/wtrcycle/users/jaerts/model_refinement_pub/results/evaporation_evaluation/regridded_pcr-globwb_evaporation/13007_pcr-globwb_et_2008_2015.nc
# [########################################] | 100% Completed |  4.9s
# 13008 finished: /gpfs/work1/0/wtrcycle/users/jaerts/model_refinement_pub/results/evaporation_evaluation/regridded_pcr-globwb_evaporation/13008_pcr-globwb_et_2008_2015.nc
# [########################################] | 100% Completed |  4.6s
# 14001 finished: /gpfs/work1/0/wtrcycle/users/jaerts/model_refinement_pub/results/evaporation_evaluation/regridded_pcr-globwb_evaporation/14001_pcr-globwb_et_2008_2015.nc
# [########################################] | 100% Completed |  5.1s
# 14002 finished: /gpfs/work1/0/wtrcycle/users/jaerts/model_refinement_pub/results/evaporation_evaluation/regridded_pcr-globwb_evaporation/14002_pcr-globwb_et_2008_2015.nc
# [########################################] | 100% Completed |  4.9s
# 14005 finished: /gpfs/work1/0/wtrcycle/users/jaerts/model_refinement_pub/results/evaporation_evaluation/regridded_pcr-globwb_evaporation/14005_pcr-globwb_et_2008_2015.nc
# [########################################] | 100% Completed | 11.7s
# 15006 finished: /gpfs/work1/0/wtrcycle/users/jaerts/model_refinement_pub/results/evaporation_evaluation/regridded_pcr-globwb_evaporation/15006_pcr-globwb_et_2008_2015.nc
# [########################################] | 100% Completed |  6.2s
# 15007 finished: /gpfs/work1/0/wtrcycle/users/jaerts/model_refinement_pub/results/evaporation_evaluation/regridded_pcr-globwb_evaporation/15007_pcr-globwb_et_2008_2015.nc
# [########################################] | 100% Completed |  4.6s
# 15010 finished: /gpfs/work1/0/wtrcycle/users/jaerts/model_refinement_pub/results/evaporation_evaluation/regridded_pcr-globwb_evaporation/15010_pcr-globwb_et_2008_2015.nc
# [########################################] | 100% Completed |  4.8s
# 15011 finished: /gpfs/work1/0/wtrcycle/users/jaerts/model_refinement_pub/results/evaporation_evaluation/regridded_pcr-globwb_evaporation/15011_pcr-globwb_et_2008_2015.nc
# [########################################] | 100% Completed |  6.8s
# 15012 finished: /gpfs/work1/0/wtrcycle/users/jaerts/model_refinement_pub/results/evaporation_evaluation/regridded_pcr-globwb_evaporation/15012_pcr-globwb_et_2008_2015.nc
# [########################################] | 100% Completed |  5.0s
# 15013 finished: /gpfs/work1/0/wtrcycle/users/jaerts/model_refinement_pub/results/evaporation_evaluation/regridded_pcr-globwb_evaporation/15013_pcr-globwb_et_2008_2015.nc
# [########################################] | 100% Completed |  4.5s
# 15014 finished: /gpfs/work1/0/wtrcycle/users/jaerts/model_refinement_pub/results/evaporation_evaluation/regridded_pcr-globwb_evaporation/15014_pcr-globwb_et_2008_2015.nc
# [########################################] | 100% Completed |  5.2s
# 15016 finished: /gpfs/work1/0/wtrcycle/users/jaerts/model_refinement_pub/results/evaporation_evaluation/regridded_pcr-globwb_evaporation/15016_pcr-globwb_et_2008_2015.nc
# [########################################] | 100% Completed |  4.4s
# 15021 finished: /gpfs/work1/0/wtrcycle/users/jaerts/model_refinement_pub/results/evaporation_evaluation/regridded_pcr-globwb_evaporation/15021_pcr-globwb_et_2008_2015.nc
# [########################################] | 100% Completed |  4.5s
# 15023 finished: /gpfs/work1/0/wtrcycle/users/jaerts/model_refinement_pub/results/evaporation_evaluation/regridded_pcr-globwb_evaporation/15023_pcr-globwb_et_2008_2015.nc
# [########################################] | 100% Completed |  4.7s
# 15024 finished: /gpfs/work1/0/wtrcycle/users/jaerts/model_refinement_pub/results/evaporation_evaluation/regridded_pcr-globwb_evaporation/15024_pcr-globwb_et_2008_2015.nc
# [########################################] | 100% Completed |  4.9s
# 15025 finished: /gpfs/work1/0/wtrcycle/users/jaerts/model_refinement_pub/results/evaporation_evaluation/regridded_pcr-globwb_evaporation/15025_pcr-globwb_et_2008_2015.nc
# [########################################] | 100% Completed |  5.3s
# 15030 finished: /gpfs/work1/0/wtrcycle/users/jaerts/model_refinement_pub/results/evaporation_evaluation/regridded_pcr-globwb_evaporation/15030_pcr-globwb_et_2008_2015.nc
# [########################################] | 100% Completed |  4.5s
# 15039 finished: /gpfs/work1/0/wtrcycle/users/jaerts/model_refinement_pub/results/evaporation_evaluation/regridded_pcr-globwb_evaporation/15039_pcr-globwb_et_2008_2015.nc
# [########################################] | 100% Completed |  4.9s
# 16001 finished: /gpfs/work1/0/wtrcycle/users/jaerts/model_refinement_pub/results/evaporation_evaluation/regridded_pcr-globwb_evaporation/16001_pcr-globwb_et_2008_2015.nc
# [########################################] | 100% Completed |  4.6s
# 16003 finished: /gpfs/work1/0/wtrcycle/users/jaerts/model_refinement_pub/results/evaporation_evaluation/regridded_pcr-globwb_evaporation/16003_pcr-globwb_et_2008_2015.nc
# [########################################] | 100% Completed |  5.1s
# 16004 finished: /gpfs/work1/0/wtrcycle/users/jaerts/model_refinement_pub/results/evaporation_evaluation/regridded_pcr-globwb_evaporation/16004_pcr-globwb_et_2008_2015.nc
# [########################################] | 100% Completed |  4.5s
# 17001 finished: /gpfs/work1/0/wtrcycle/users/jaerts/model_refinement_pub/results/evaporation_evaluation/regridded_pcr-globwb_evaporation/17001_pcr-globwb_et_2008_2015.nc
# [########################################] | 100% Completed |  4.4s
# 17003 finished: /gpfs/work1/0/wtrcycle/users/jaerts/model_refinement_pub/results/evaporation_evaluation/regridded_pcr-globwb_evaporation/17003_pcr-globwb_et_2008_2015.nc
# [########################################] | 100% Completed |  4.5s
# 17004 finished: /gpfs/work1/0/wtrcycle/users/jaerts/model_refinement_pub/results/evaporation_evaluation/regridded_pcr-globwb_evaporation/17004_pcr-globwb_et_2008_2015.nc
# [########################################] | 100% Completed |  4.6s
# 17005 finished: /gpfs/work1/0/wtrcycle/users/jaerts/model_refinement_pub/results/evaporation_evaluation/regridded_pcr-globwb_evaporation/17005_pcr-globwb_et_2008_2015.nc
# [########################################] | 100% Completed |  4.2s
# 17015 finished: /gpfs/work1/0/wtrcycle/users/jaerts/model_refinement_pub/results/evaporation_evaluation/regridded_pcr-globwb_evaporation/17015_pcr-globwb_et_2008_2015.nc
# [########################################] | 100% Completed |  4.4s
# 18001 finished: /gpfs/work1/0/wtrcycle/users/jaerts/model_refinement_pub/results/evaporation_evaluation/regridded_pcr-globwb_evaporation/18001_pcr-globwb_et_2008_2015.nc
# [########################################] | 100% Completed |  4.6s
# 18002 finished: /gpfs/work1/0/wtrcycle/users/jaerts/model_refinement_pub/results/evaporation_evaluation/regridded_pcr-globwb_evaporation/18002_pcr-globwb_et_2008_2015.nc
# [########################################] | 100% Completed |  5.0s
# 18003 finished: /gpfs/work1/0/wtrcycle/users/jaerts/model_refinement_pub/results/evaporation_evaluation/regridded_pcr-globwb_evaporation/18003_pcr-globwb_et_2008_2015.nc
# [########################################] | 100% Completed |  4.6s
# 18008 finished: /gpfs/work1/0/wtrcycle/users/jaerts/model_refinement_pub/results/evaporation_evaluation/regridded_pcr-globwb_evaporation/18008_pcr-globwb_et_2008_2015.nc
# [########################################] | 100% Completed |  5.0s
# 18010 finished: /gpfs/work1/0/wtrcycle/users/jaerts/model_refinement_pub/results/evaporation_evaluation/regridded_pcr-globwb_evaporation/18010_pcr-globwb_et_2008_2015.nc
# [########################################] | 100% Completed |  5.2s
# 18011 finished: /gpfs/work1/0/wtrcycle/users/jaerts/model_refinement_pub/results/evaporation_evaluation/regridded_pcr-globwb_evaporation/18011_pcr-globwb_et_2008_2015.nc
# [########################################] | 100% Completed |  4.4s
# 18014 finished: /gpfs/work1/0/wtrcycle/users/jaerts/model_refinement_pub/results/evaporation_evaluation/regridded_pcr-globwb_evaporation/18014_pcr-globwb_et_2008_2015.nc
# [########################################] | 100% Completed |  4.8s
# 19001 finished: /gpfs/work1/0/wtrcycle/users/jaerts/model_refinement_pub/results/evaporation_evaluation/regridded_pcr-globwb_evaporation/19001_pcr-globwb_et_2008_2015.nc
# [########################################] | 100% Completed |  4.6s
# 19006 finished: /gpfs/work1/0/wtrcycle/users/jaerts/model_refinement_pub/results/evaporation_evaluation/regridded_pcr-globwb_evaporation/19006_pcr-globwb_et_2008_2015.nc
# [########################################] | 100% Completed |  4.3s
# 19010 finished: /gpfs/work1/0/wtrcycle/users/jaerts/model_refinement_pub/results/evaporation_evaluation/regridded_pcr-globwb_evaporation/19010_pcr-globwb_et_2008_2015.nc
# [########################################] | 100% Completed |  4.3s
# 19017 finished: /gpfs/work1/0/wtrcycle/users/jaerts/model_refinement_pub/results/evaporation_evaluation/regridded_pcr-globwb_evaporation/19017_pcr-globwb_et_2008_2015.nc
# [########################################] | 100% Completed |  4.2s
# 19020 finished: /gpfs/work1/0/wtrcycle/users/jaerts/model_refinement_pub/results/evaporation_evaluation/regridded_pcr-globwb_evaporation/19020_pcr-globwb_et_2008_2015.nc
# [########################################] | 100% Completed |  4.1s
# 20002 finished: /gpfs/work1/0/wtrcycle/users/jaerts/model_refinement_pub/results/evaporation_evaluation/regridded_pcr-globwb_evaporation/20002_pcr-globwb_et_2008_2015.nc
# [########################################] | 100% Completed |  4.5s
# 20003 finished: /gpfs/work1/0/wtrcycle/users/jaerts/model_refinement_pub/results/evaporation_evaluation/regridded_pcr-globwb_evaporation/20003_pcr-globwb_et_2008_2015.nc
# [########################################] | 100% Completed |  4.4s
# 20007 finished: /gpfs/work1/0/wtrcycle/users/jaerts/model_refinement_pub/results/evaporation_evaluation/regridded_pcr-globwb_evaporation/20007_pcr-globwb_et_2008_2015.nc
# [########################################] | 100% Completed |  5.4s
# 2001 finished: /gpfs/work1/0/wtrcycle/users/jaerts/model_refinement_pub/results/evaporation_evaluation/regridded_pcr-globwb_evaporation/2001_pcr-globwb_et_2008_2015.nc
# [########################################] | 100% Completed |  4.9s
# 2002 finished: /gpfs/work1/0/wtrcycle/users/jaerts/model_refinement_pub/results/evaporation_evaluation/regridded_pcr-globwb_evaporation/2002_pcr-globwb_et_2008_2015.nc
# [########################################] | 100% Completed |  5.2s
# 21003 finished: /gpfs/work1/0/wtrcycle/users/jaerts/model_refinement_pub/results/evaporation_evaluation/regridded_pcr-globwb_evaporation/21003_pcr-globwb_et_2008_2015.nc
# [########################################] | 100% Completed |  6.5s
# 21006 finished: /gpfs/work1/0/wtrcycle/users/jaerts/model_refinement_pub/results/evaporation_evaluation/regridded_pcr-globwb_evaporation/21006_pcr-globwb_et_2008_2015.nc
# [########################################] | 100% Completed |  5.8s
# 21008 finished: /gpfs/work1/0/wtrcycle/users/jaerts/model_refinement_pub/results/evaporation_evaluation/regridded_pcr-globwb_evaporation/21008_pcr-globwb_et_2008_2015.nc
# [########################################] | 100% Completed |  9.6s
# 21009 finished: /gpfs/work1/0/wtrcycle/users/jaerts/model_refinement_pub/results/evaporation_evaluation/regridded_pcr-globwb_evaporation/21009_pcr-globwb_et_2008_2015.nc
# [########################################] | 100% Completed |  4.8s
# 21011 finished: /gpfs/work1/0/wtrcycle/users/jaerts/model_refinement_pub/results/evaporation_evaluation/regridded_pcr-globwb_evaporation/21011_pcr-globwb_et_2008_2015.nc
# [########################################] | 100% Completed |  4.7s
# 21012 finished: /gpfs/work1/0/wtrcycle/users/jaerts/model_refinement_pub/results/evaporation_evaluation/regridded_pcr-globwb_evaporation/21012_pcr-globwb_et_2008_2015.nc
# [########################################] | 100% Completed |  4.5s
# 21013 finished: /gpfs/work1/0/wtrcycle/users/jaerts/model_refinement_pub/results/evaporation_evaluation/regridded_pcr-globwb_evaporation/21013_pcr-globwb_et_2008_2015.nc
# [########################################] | 100% Completed |  4.4s
# 21015 finished: /gpfs/work1/0/wtrcycle/users/jaerts/model_refinement_pub/results/evaporation_evaluation/regridded_pcr-globwb_evaporation/21015_pcr-globwb_et_2008_2015.nc
# [########################################] | 100% Completed |  4.5s
# 21016 finished: /gpfs/work1/0/wtrcycle/users/jaerts/model_refinement_pub/results/evaporation_evaluation/regridded_pcr-globwb_evaporation/21016_pcr-globwb_et_2008_2015.nc
# [########################################] | 100% Completed |  4.4s
# 21017 finished: /gpfs/work1/0/wtrcycle/users/jaerts/model_refinement_pub/results/evaporation_evaluation/regridded_pcr-globwb_evaporation/21017_pcr-globwb_et_2008_2015.nc
# [########################################] | 100% Completed |  4.5s
# 21018 finished: /gpfs/work1/0/wtrcycle/users/jaerts/model_refinement_pub/results/evaporation_evaluation/regridded_pcr-globwb_evaporation/21018_pcr-globwb_et_2008_2015.nc
# [########################################] | 100% Completed |  5.0s
# 21022 finished: /gpfs/work1/0/wtrcycle/users/jaerts/model_refinement_pub/results/evaporation_evaluation/regridded_pcr-globwb_evaporation/21022_pcr-globwb_et_2008_2015.nc
# [########################################] | 100% Completed |  4.5s
# 21023 finished: /gpfs/work1/0/wtrcycle/users/jaerts/model_refinement_pub/results/evaporation_evaluation/regridded_pcr-globwb_evaporation/21023_pcr-globwb_et_2008_2015.nc
# [########################################] | 100% Completed |  4.4s
# 21024 finished: /gpfs/work1/0/wtrcycle/users/jaerts/model_refinement_pub/results/evaporation_evaluation/regridded_pcr-globwb_evaporation/21024_pcr-globwb_et_2008_2015.nc
# [########################################] | 100% Completed |  4.5s
# 21026 finished: /gpfs/work1/0/wtrcycle/users/jaerts/model_refinement_pub/results/evaporation_evaluation/regridded_pcr-globwb_evaporation/21026_pcr-globwb_et_2008_2015.nc
# [########################################] | 100% Completed |  4.7s
# 21027 finished: /gpfs/work1/0/wtrcycle/users/jaerts/model_refinement_pub/results/evaporation_evaluation/regridded_pcr-globwb_evaporation/21027_pcr-globwb_et_2008_2015.nc
# [########################################] | 100% Completed |  5.2s
# 22001 finished: /gpfs/work1/0/wtrcycle/users/jaerts/model_refinement_pub/results/evaporation_evaluation/regridded_pcr-globwb_evaporation/22001_pcr-globwb_et_2008_2015.nc
# [########################################] | 100% Completed |  4.4s
# 22006 finished: /gpfs/work1/0/wtrcycle/users/jaerts/model_refinement_pub/results/evaporation_evaluation/regridded_pcr-globwb_evaporation/22006_pcr-globwb_et_2008_2015.nc
# [########################################] | 100% Completed |  4.8s
# 22007 finished: /gpfs/work1/0/wtrcycle/users/jaerts/model_refinement_pub/results/evaporation_evaluation/regridded_pcr-globwb_evaporation/22007_pcr-globwb_et_2008_2015.nc
# [########################################] | 100% Completed |  7.0s
# 22009 finished: /gpfs/work1/0/wtrcycle/users/jaerts/model_refinement_pub/results/evaporation_evaluation/regridded_pcr-globwb_evaporation/22009_pcr-globwb_et_2008_2015.nc
# [########################################] | 100% Completed |  7.0s
# 23001 finished: /gpfs/work1/0/wtrcycle/users/jaerts/model_refinement_pub/results/evaporation_evaluation/regridded_pcr-globwb_evaporation/23001_pcr-globwb_et_2008_2015.nc
# [########################################] | 100% Completed |  5.1s
# 23004 finished: /gpfs/work1/0/wtrcycle/users/jaerts/model_refinement_pub/results/evaporation_evaluation/regridded_pcr-globwb_evaporation/23004_pcr-globwb_et_2008_2015.nc
# [########################################] | 100% Completed |  4.5s
# 23006 finished: /gpfs/work1/0/wtrcycle/users/jaerts/model_refinement_pub/results/evaporation_evaluation/regridded_pcr-globwb_evaporation/23006_pcr-globwb_et_2008_2015.nc
# [########################################] | 100% Completed |  4.3s
# 23007 finished: /gpfs/work1/0/wtrcycle/users/jaerts/model_refinement_pub/results/evaporation_evaluation/regridded_pcr-globwb_evaporation/23007_pcr-globwb_et_2008_2015.nc
# [########################################] | 100% Completed |  5.3s
# 23008 finished: /gpfs/work1/0/wtrcycle/users/jaerts/model_refinement_pub/results/evaporation_evaluation/regridded_pcr-globwb_evaporation/23008_pcr-globwb_et_2008_2015.nc
# [########################################] | 100% Completed |  4.3s
# 23011 finished: /gpfs/work1/0/wtrcycle/users/jaerts/model_refinement_pub/results/evaporation_evaluation/regridded_pcr-globwb_evaporation/23011_pcr-globwb_et_2008_2015.nc
# [########################################] | 100% Completed |  4.1s
# 23016 finished: /gpfs/work1/0/wtrcycle/users/jaerts/model_refinement_pub/results/evaporation_evaluation/regridded_pcr-globwb_evaporation/23016_pcr-globwb_et_2008_2015.nc
# [########################################] | 100% Completed |  4.8s
# 24001 finished: /gpfs/work1/0/wtrcycle/users/jaerts/model_refinement_pub/results/evaporation_evaluation/regridded_pcr-globwb_evaporation/24001_pcr-globwb_et_2008_2015.nc
# [########################################] | 100% Completed |  4.8s
# 24003 finished: /gpfs/work1/0/wtrcycle/users/jaerts/model_refinement_pub/results/evaporation_evaluation/regridded_pcr-globwb_evaporation/24003_pcr-globwb_et_2008_2015.nc
# [########################################] | 100% Completed |  4.5s
# 24004 finished: /gpfs/work1/0/wtrcycle/users/jaerts/model_refinement_pub/results/evaporation_evaluation/regridded_pcr-globwb_evaporation/24004_pcr-globwb_et_2008_2015.nc
# [########################################] | 100% Completed |  4.9s
# 24005 finished: /gpfs/work1/0/wtrcycle/users/jaerts/model_refinement_pub/results/evaporation_evaluation/regridded_pcr-globwb_evaporation/24005_pcr-globwb_et_2008_2015.nc
# [########################################] | 100% Completed |  5.4s
# 25001 finished: /gpfs/work1/0/wtrcycle/users/jaerts/model_refinement_pub/results/evaporation_evaluation/regridded_pcr-globwb_evaporation/25001_pcr-globwb_et_2008_2015.nc
# [########################################] | 100% Completed |  4.3s
# 25003 finished: /gpfs/work1/0/wtrcycle/users/jaerts/model_refinement_pub/results/evaporation_evaluation/regridded_pcr-globwb_evaporation/25003_pcr-globwb_et_2008_2015.nc
# [########################################] | 100% Completed |  4.1s
# 25006 finished: /gpfs/work1/0/wtrcycle/users/jaerts/model_refinement_pub/results/evaporation_evaluation/regridded_pcr-globwb_evaporation/25006_pcr-globwb_et_2008_2015.nc
# [########################################] | 100% Completed |  4.1s
# 25012 finished: /gpfs/work1/0/wtrcycle/users/jaerts/model_refinement_pub/results/evaporation_evaluation/regridded_pcr-globwb_evaporation/25012_pcr-globwb_et_2008_2015.nc
# [########################################] | 100% Completed |  4.5s
# 25020 finished: /gpfs/work1/0/wtrcycle/users/jaerts/model_refinement_pub/results/evaporation_evaluation/regridded_pcr-globwb_evaporation/25020_pcr-globwb_et_2008_2015.nc
# [########################################] | 100% Completed |  4.3s
# 25021 finished: /gpfs/work1/0/wtrcycle/users/jaerts/model_refinement_pub/results/evaporation_evaluation/regridded_pcr-globwb_evaporation/25021_pcr-globwb_et_2008_2015.nc
# [########################################] | 100% Completed |  4.4s
# 25029 finished: /gpfs/work1/0/wtrcycle/users/jaerts/model_refinement_pub/results/evaporation_evaluation/regridded_pcr-globwb_evaporation/25029_pcr-globwb_et_2008_2015.nc
# [########################################] | 100% Completed |  4.3s
# 26003 finished: /gpfs/work1/0/wtrcycle/users/jaerts/model_refinement_pub/results/evaporation_evaluation/regridded_pcr-globwb_evaporation/26003_pcr-globwb_et_2008_2015.nc
# [########################################] | 100% Completed |  4.5s
# 26005 finished: /gpfs/work1/0/wtrcycle/users/jaerts/model_refinement_pub/results/evaporation_evaluation/regridded_pcr-globwb_evaporation/26005_pcr-globwb_et_2008_2015.nc
# [########################################] | 100% Completed |  4.9s
# 26006 finished: /gpfs/work1/0/wtrcycle/users/jaerts/model_refinement_pub/results/evaporation_evaluation/regridded_pcr-globwb_evaporation/26006_pcr-globwb_et_2008_2015.nc
# [########################################] | 100% Completed |  5.4s
# 26008 finished: /gpfs/work1/0/wtrcycle/users/jaerts/model_refinement_pub/results/evaporation_evaluation/regridded_pcr-globwb_evaporation/26008_pcr-globwb_et_2008_2015.nc
# [########################################] | 100% Completed |  5.3s
# 26009 finished: /gpfs/work1/0/wtrcycle/users/jaerts/model_refinement_pub/results/evaporation_evaluation/regridded_pcr-globwb_evaporation/26009_pcr-globwb_et_2008_2015.nc
# [########################################] | 100% Completed |  6.1s
# 27001 finished: /gpfs/work1/0/wtrcycle/users/jaerts/model_refinement_pub/results/evaporation_evaluation/regridded_pcr-globwb_evaporation/27001_pcr-globwb_et_2008_2015.nc
# [########################################] | 100% Completed |  7.3s
# 27002 finished: /gpfs/work1/0/wtrcycle/users/jaerts/model_refinement_pub/results/evaporation_evaluation/regridded_pcr-globwb_evaporation/27002_pcr-globwb_et_2008_2015.nc
# [########################################] | 100% Completed |  7.4s
# 27003 finished: /gpfs/work1/0/wtrcycle/users/jaerts/model_refinement_pub/results/evaporation_evaluation/regridded_pcr-globwb_evaporation/27003_pcr-globwb_et_2008_2015.nc
# [########################################] | 100% Completed |  4.9s
# 27006 finished: /gpfs/work1/0/wtrcycle/users/jaerts/model_refinement_pub/results/evaporation_evaluation/regridded_pcr-globwb_evaporation/27006_pcr-globwb_et_2008_2015.nc
# [########################################] | 100% Completed |  5.8s
# 27007 finished: /gpfs/work1/0/wtrcycle/users/jaerts/model_refinement_pub/results/evaporation_evaluation/regridded_pcr-globwb_evaporation/27007_pcr-globwb_et_2008_2015.nc
# [########################################] | 100% Completed |  8.8s
# 27009 finished: /gpfs/work1/0/wtrcycle/users/jaerts/model_refinement_pub/results/evaporation_evaluation/regridded_pcr-globwb_evaporation/27009_pcr-globwb_et_2008_2015.nc
# [########################################] | 100% Completed |  6.3s
# 27021 finished: /gpfs/work1/0/wtrcycle/users/jaerts/model_refinement_pub/results/evaporation_evaluation/regridded_pcr-globwb_evaporation/27021_pcr-globwb_et_2008_2015.nc
# [########################################] | 100% Completed |  4.4s
# 27023 finished: /gpfs/work1/0/wtrcycle/users/jaerts/model_refinement_pub/results/evaporation_evaluation/regridded_pcr-globwb_evaporation/27023_pcr-globwb_et_2008_2015.nc
# [########################################] | 100% Completed |  5.0s
# 27025 finished: /gpfs/work1/0/wtrcycle/users/jaerts/model_refinement_pub/results/evaporation_evaluation/regridded_pcr-globwb_evaporation/27025_pcr-globwb_et_2008_2015.nc
# [########################################] | 100% Completed |  4.4s
# 27026 finished: /gpfs/work1/0/wtrcycle/users/jaerts/model_refinement_pub/results/evaporation_evaluation/regridded_pcr-globwb_evaporation/27026_pcr-globwb_et_2008_2015.nc
# [########################################] | 100% Completed |  5.5s
# 27029 finished: /gpfs/work1/0/wtrcycle/users/jaerts/model_refinement_pub/results/evaporation_evaluation/regridded_pcr-globwb_evaporation/27029_pcr-globwb_et_2008_2015.nc
# [########################################] | 100% Completed |  4.5s
# 27030 finished: /gpfs/work1/0/wtrcycle/users/jaerts/model_refinement_pub/results/evaporation_evaluation/regridded_pcr-globwb_evaporation/27030_pcr-globwb_et_2008_2015.nc
# [########################################] | 100% Completed |  4.0s
# 27032 finished: /gpfs/work1/0/wtrcycle/users/jaerts/model_refinement_pub/results/evaporation_evaluation/regridded_pcr-globwb_evaporation/27032_pcr-globwb_et_2008_2015.nc
# [########################################] | 100% Completed |  4.3s
# 27034 finished: /gpfs/work1/0/wtrcycle/users/jaerts/model_refinement_pub/results/evaporation_evaluation/regridded_pcr-globwb_evaporation/27034_pcr-globwb_et_2008_2015.nc
# [########################################] | 100% Completed |  4.4s
# 27035 finished: /gpfs/work1/0/wtrcycle/users/jaerts/model_refinement_pub/results/evaporation_evaluation/regridded_pcr-globwb_evaporation/27035_pcr-globwb_et_2008_2015.nc
# [########################################] | 100% Completed |  3.9s
# 27038 finished: /gpfs/work1/0/wtrcycle/users/jaerts/model_refinement_pub/results/evaporation_evaluation/regridded_pcr-globwb_evaporation/27038_pcr-globwb_et_2008_2015.nc
# [########################################] | 100% Completed |  5.8s
# 27041 finished: /gpfs/work1/0/wtrcycle/users/jaerts/model_refinement_pub/results/evaporation_evaluation/regridded_pcr-globwb_evaporation/27041_pcr-globwb_et_2008_2015.nc
# [########################################] | 100% Completed |  4.1s
# 27042 finished: /gpfs/work1/0/wtrcycle/users/jaerts/model_refinement_pub/results/evaporation_evaluation/regridded_pcr-globwb_evaporation/27042_pcr-globwb_et_2008_2015.nc
# [########################################] | 100% Completed |  4.5s
# 27043 finished: /gpfs/work1/0/wtrcycle/users/jaerts/model_refinement_pub/results/evaporation_evaluation/regridded_pcr-globwb_evaporation/27043_pcr-globwb_et_2008_2015.nc
# [########################################] | 100% Completed |  3.9s
# 27047 finished: /gpfs/work1/0/wtrcycle/users/jaerts/model_refinement_pub/results/evaporation_evaluation/regridded_pcr-globwb_evaporation/27047_pcr-globwb_et_2008_2015.nc
# [########################################] | 100% Completed |  4.2s
# 27049 finished: /gpfs/work1/0/wtrcycle/users/jaerts/model_refinement_pub/results/evaporation_evaluation/regridded_pcr-globwb_evaporation/27049_pcr-globwb_et_2008_2015.nc
# [########################################] | 100% Completed |  3.9s
# 27051 finished: /gpfs/work1/0/wtrcycle/users/jaerts/model_refinement_pub/results/evaporation_evaluation/regridded_pcr-globwb_evaporation/27051_pcr-globwb_et_2008_2015.nc
# [########################################] | 100% Completed |  4.6s
# 27062 finished: /gpfs/work1/0/wtrcycle/users/jaerts/model_refinement_pub/results/evaporation_evaluation/regridded_pcr-globwb_evaporation/27062_pcr-globwb_et_2008_2015.nc
# [########################################] | 100% Completed |  3.9s
# 27064 finished: /gpfs/work1/0/wtrcycle/users/jaerts/model_refinement_pub/results/evaporation_evaluation/regridded_pcr-globwb_evaporation/27064_pcr-globwb_et_2008_2015.nc
# [########################################] | 100% Completed |  3.9s
# 27065 finished: /gpfs/work1/0/wtrcycle/users/jaerts/model_refinement_pub/results/evaporation_evaluation/regridded_pcr-globwb_evaporation/27065_pcr-globwb_et_2008_2015.nc
# [########################################] | 100% Completed |  5.4s
# 27071 finished: /gpfs/work1/0/wtrcycle/users/jaerts/model_refinement_pub/results/evaporation_evaluation/regridded_pcr-globwb_evaporation/27071_pcr-globwb_et_2008_2015.nc
# [######                                  ] | 16% Completed |  2.7s
