# %% [markdown]
# ## Preprocess soil moisture reference observations

# %%
import warnings
warnings.filterwarnings("ignore", category=UserWarning)
warnings.filterwarnings("ignore", category=DeprecationWarning)

# %%
from glob import glob
from pathlib import Path

import os
import iris
import xarray as xr
import pandas as pd
from esmvalcore.preprocessor import regrid
from pathos.threading import ThreadPool as Pool
from dask.diagnostics import ProgressBar

# %% [markdown]
# ## Set Paths

# %%
# Set Paths
ROOT = Path('/gpfs/work1/0/wtrcycle/users/jaerts/model_refinement_pub/')
AUXDIR = Path(f"{ROOT}/aux_data/")
OBSDIR = Path(f"{ROOT}/observations/")
MODELS = Path(f'{ROOT}/model_parameters/wflow_sbm/')
OUTPUT = Path(f'{OBSDIR}/soil_moisture/regridded_HydroJULES/')

# %% [markdown]
# ## Config

# %%
# Get available basin IDs wflow_sbm
basin_dirs = glob(f'{MODELS}/*')
basin_ids = [s.split('/')[-1] for s in basin_dirs]
basin_ids.sort()

# Amount of available cores
cores_available = 5

# %% [markdown]
# ## Preprocess function

# %%
def prep_observations(basin_id):
    # Set basin directory
    BASINDIR = f'{MODELS}/{basin_id}/'

    # Open netCDF file as an example grid from the model directory
    cube_example = iris.load(f'{BASINDIR}/staticmaps.nc')[1]

    # Guess bounds   
    cube_example.coord('y').guess_bounds()
    cube_example.coord('x').guess_bounds()

    # Rename Coords
    cube_example.coord('y').rename('latitude')
    cube_example.coord('x').rename('longitude')

    cube_example.coord('latitude').units = 'degrees'
    cube_example.coord('longitude').units = 'degrees'

    # Load observation netCDF files
    file = f'{OBSDIR}/soil_moisture/HydroJULES_soil_moisture/merge_1km_tc_ref_smap.nc'
    cube_obs = iris.load(file)[0]

    # Guess bounds   
    cube_obs.coord('latitude').guess_bounds()
    cube_obs.coord('longitude').guess_bounds()

    # Regrid observation cube
    cube_out = regrid(cube_obs, cube_example, scheme='area_weighted')

    # Create obs dataset
    da = xr.DataArray.from_iris(cube_out)

    # Create mask dataset
    mask = xr.open_dataset(f'{BASINDIR}/staticmaps.nc').mask
    mask = mask.rename({'y':'latitude','x':'longitude'})

    # Apply mask
    da = da.where(mask>0)
    
    # Calculate time series
    da = da.mean(['latitude','longitude'])
    da = da.chunk(chunks='auto')
    da = da.drop('spatial_ref')
    
    # Output filename
    output_fname = f'{OUTPUT}/{basin_id}_soil_moisture_ref_2015_2017.nc'

    # Save to netcdf
    write_job = da.to_netcdf(output_fname, compute=False)
    with ProgressBar():
        write_job.compute()
    
    return print(f'{basin_id} finished: {output_fname}')

# %% [markdown]
# ## Parallel Run Function

# %%
def parallel_run(
    basin_ids,
    threads=cores_available,
    ):
    
    # Set number of threads (cores) used for parallel run and map threads
    if threads is None:
        pool = Pool()
    else:
        pool = Pool(nodes=threads)
    # Run parallel models
    pool.map(
        prep_observations,
        basin_ids,
        )
    return

# %% [markdown]
# ## Sort basins by size

# %%
# Sort by basin size
def sort_basin_ids_by_size(basin_ids):
    sizes = []
    for basin_id in basin_ids:
        size = os.path.getsize(f'{MODELS}/{basin_id}/staticmaps.nc')
        sizes.append(size)

    df = pd.DataFrame()
    df['basin_id'] = basin_ids
    df['size'] = sizes
    df = df.sort_values('size')

    basin_ids = df.basin_id.to_list()
    
    return basin_ids

basin_ids_sorted = sort_basin_ids_by_size(basin_ids)

# %% [markdown]
# # Run parallel function

# %%
# Run function
parallel_run(basin_ids_sorted)
# Out:
# [                                        ] | 0% Completed |  0.0s7s
# 41016 finished: /gpfs/work1/0/wtrcycle/users/jaerts/model_refinement_pub/observations/soil_moisture/regridded_HydroJULES/41016_soil_moisture_ref_2015_2017.nc
# [########################################] | 100% Completed | 59.9s
# [#                                       ] | 2% Completed | 30.6s80005 finished: /gpfs/work1/0/wtrcycle/users/jaerts/model_refinement_pub/observations/soil_moisture/regridded_HydroJULES/80005_soil_moisture_ref_2015_2017.nc
# [######################                  ] | 56% Completed | 40.9ss
# 41027 finished: /gpfs/work1/0/wtrcycle/users/jaerts/model_refinement_pub/observations/soil_moisture/regridded_HydroJULES/41027_soil_moisture_ref_2015_2017.nc
# [########################################] | 100% Completed | 41.8s
# 40033 finished: /gpfs/work1/0/wtrcycle/users/jaerts/model_refinement_pub/observations/soil_moisture/regridded_HydroJULES/40033_soil_moisture_ref_2015_2017.nc
# [########################################] | 100% Completed | 41.8s
# 37018 finished: /gpfs/work1/0/wtrcycle/users/jaerts/model_refinement_pub/observations/soil_moisture/regridded_HydroJULES/37018_soil_moisture_ref_2015_2017.nc
# [########################################] | 100% Completed | 27.6s
# 102001 finished: /gpfs/work1/0/wtrcycle/users/jaerts/model_refinement_pub/observations/soil_moisture/regridded_HydroJULES/102001_soil_moisture_ref_2015_2017.nc
# [########################################] | 100% Completed | 14.6s
# 31023 finished: /gpfs/work1/0/wtrcycle/users/jaerts/model_refinement_pub/observations/soil_moisture/regridded_HydroJULES/31023_soil_moisture_ref_2015_2017.nc
# [########################################] | 100% Completed | 27.9s
# 39049 finished: /gpfs/work1/0/wtrcycle/users/jaerts/model_refinement_pub/observations/soil_moisture/regridded_HydroJULES/39049_soil_moisture_ref_2015_2017.nc
# [########################################] | 100% Completed | 15.4s
# 42026 finished: /gpfs/work1/0/wtrcycle/users/jaerts/model_refinement_pub/observations/soil_moisture/regridded_HydroJULES/42026_soil_moisture_ref_2015_2017.nc
# [########################################] | 100% Completed | 14.5s
# 30004 finished: /gpfs/work1/0/wtrcycle/users/jaerts/model_refinement_pub/observations/soil_moisture/regridded_HydroJULES/30004_soil_moisture_ref_2015_2017.nc
# [########################################] | 100% Completed | 14.5s
# 36010 finished: /gpfs/work1/0/wtrcycle/users/jaerts/model_refinement_pub/observations/soil_moisture/regridded_HydroJULES/36010_soil_moisture_ref_2015_2017.nc
# [########################################] | 100% Completed | 27.9s
# 80004 finished: /gpfs/work1/0/wtrcycle/users/jaerts/model_refinement_pub/observations/soil_moisture/regridded_HydroJULES/80004_soil_moisture_ref_2015_2017.nc
# [########################################] | 100% Completed | 14.8s
# 38014 finished: /gpfs/work1/0/wtrcycle/users/jaerts/model_refinement_pub/observations/soil_moisture/regridded_HydroJULES/38014_soil_moisture_ref_2015_2017.nc
# [########################################] | 100% Completed | 30.1s
# 54034 finished: /gpfs/work1/0/wtrcycle/users/jaerts/model_refinement_pub/observations/soil_moisture/regridded_HydroJULES/54034_soil_moisture_ref_2015_2017.nc
# [########################################] | 100% Completed | 17.5s
# 33031 finished: /gpfs/work1/0/wtrcycle/users/jaerts/model_refinement_pub/observations/soil_moisture/regridded_HydroJULES/33031_soil_moisture_ref_2015_2017.nc
# [########################################] | 100% Completed | 15.9s
# 36009 finished: /gpfs/work1/0/wtrcycle/users/jaerts/model_refinement_pub/observations/soil_moisture/regridded_HydroJULES/36009_soil_moisture_ref_2015_2017.nc
# [########################################] | 100% Completed | 21.3s
# [#                                       ] | 4% Completed |  8.2sent_pub/observations/soil_moisture/regridded_HydroJULES/80003_soil_moisture_ref_2015_2017.nc
# [########################################] | 100% Completed | 28.0s
# 19010 finished: /gpfs/work1/0/wtrcycle/users/jaerts/model_refinement_pub/observations/soil_moisture/regridded_HydroJULES/19010_soil_moisture_ref_2015_2017.nc
# [########################################] | 100% Completed | 28.5s
# 84020 finished: /gpfs/work1/0/wtrcycle/users/jaerts/model_refinement_pub/observations/soil_moisture/regridded_HydroJULES/84020_soil_moisture_ref_2015_2017.nc
# [########################################] | 100% Completed | 14.5s
# 14005 finished: /gpfs/work1/0/wtrcycle/users/jaerts/model_refinement_pub/observations/soil_moisture/regridded_HydroJULES/14005_soil_moisture_ref_2015_2017.nc
# [########################################] | 100% Completed | 14.4s
# 101005 finished: /gpfs/work1/0/wtrcycle/users/jaerts/model_refinement_pub/observations/soil_moisture/regridded_HydroJULES/101005_soil_moisture_ref_2015_2017.nc
# [#                                       ] | 2% Completed | 18.1sss
# [#                                       ] | 4% Completed | 21.0ss39052 finished: /gpfs/work1/0/wtrcycle/users/jaerts/model_refinement_pub/observations/soil_moisture/regridded_HydroJULES/39052_soil_moisture_ref_2015_2017.nc
# [#####################                   ] | 54% Completed | 28.0ss
# 76011 finished: /gpfs/work1/0/wtrcycle/users/jaerts/model_refinement_pub/observations/soil_moisture/regridded_HydroJULES/76011_soil_moisture_ref_2015_2017.nc
# [########################################] | 100% Completed | 42.5s
# 36003 finished: /gpfs/work1/0/wtrcycle/users/jaerts/model_refinement_pub/observations/soil_moisture/regridded_HydroJULES/36003_soil_moisture_ref_2015_2017.nc
# [########################################] | 100% Completed | 14.8s
# 72014 finished: /gpfs/work1/0/wtrcycle/users/jaerts/model_refinement_pub/observations/soil_moisture/regridded_HydroJULES/72014_soil_moisture_ref_2015_2017.nc
# [########################################] | 100% Completed | 17.2s
# 54060 finished: /gpfs/work1/0/wtrcycle/users/jaerts/model_refinement_pub/observations/soil_moisture/regridded_HydroJULES/54060_soil_moisture_ref_2015_2017.nc
# [########################################] | 100% Completed | 27.9s
# 21017 finished: /gpfs/work1/0/wtrcycle/users/jaerts/model_refinement_pub/observations/soil_moisture/regridded_HydroJULES/21017_soil_moisture_ref_2015_2017.nc
# [########################################] | 100% Completed | 15.1s
# [                                        ] | 0% Completed |  0.8s39061 finished: /gpfs/work1/0/wtrcycle/users/jaerts/model_refinement_pub/observations/soil_moisture/regridded_HydroJULES/39061_soil_moisture_ref_2015_2017.nc
# [#####################                   ] | 54% Completed | 14.2ss
# 66004 finished: /gpfs/work1/0/wtrcycle/users/jaerts/model_refinement_pub/observations/soil_moisture/regridded_HydroJULES/66004_soil_moisture_ref_2015_2017.nc
# [########################################] | 100% Completed | 14.6s
# 40006 finished: /gpfs/work1/0/wtrcycle/users/jaerts/model_refinement_pub/observations/soil_moisture/regridded_HydroJULES/40006_soil_moisture_ref_2015_2017.nc
# [########################################] | 100% Completed | 15.0s
# 27032 finished: /gpfs/work1/0/wtrcycle/users/jaerts/model_refinement_pub/observations/soil_moisture/regridded_HydroJULES/27032_soil_moisture_ref_2015_2017.nc
# [########################################] | 100% Completed | 14.9s
# 23016 finished: /gpfs/work1/0/wtrcycle/users/jaerts/model_refinement_pub/observations/soil_moisture/regridded_HydroJULES/23016_soil_moisture_ref_2015_2017.nc
# [########################################] | 100% Completed | 27.6s
# 18017 finished: /gpfs/work1/0/wtrcycle/users/jaerts/model_refinement_pub/observations/soil_moisture/regridded_HydroJULES/18017_soil_moisture_ref_2015_2017.nc
# [########################################] | 100% Completed | 29.2s
# 24004 finished: /gpfs/work1/0/wtrcycle/users/jaerts/model_refinement_pub/observations/soil_moisture/regridded_HydroJULES/24004_soil_moisture_ref_2015_2017.nc
# [########################################] | 100% Completed | 14.8s
# 72007 finished: /gpfs/work1/0/wtrcycle/users/jaerts/model_refinement_pub/observations/soil_moisture/regridded_HydroJULES/72007_soil_moisture_ref_2015_2017.nc
# [########################################] | 100% Completed | 14.5s
# 39017 finished: /gpfs/work1/0/wtrcycle/users/jaerts/model_refinement_pub/observations/soil_moisture/regridded_HydroJULES/39017_soil_moisture_ref_2015_2017.nc
# [########################################] | 100% Completed | 28.3s
# 37033 finished: /gpfs/work1/0/wtrcycle/users/jaerts/model_refinement_pub/observations/soil_moisture/regridded_HydroJULES/37033_soil_moisture_ref_2015_2017.nc
# [                                        ] | 0% Completed |  0.0s3s
# 28055 finished: /gpfs/work1/0/wtrcycle/users/jaerts/model_refinement_pub/observations/soil_moisture/regridded_HydroJULES/28055_soil_moisture_ref_2015_2017.nc
# [########################################] | 100% Completed | 28.0s
# 52007 finished: /gpfs/work1/0/wtrcycle/users/jaerts/model_refinement_pub/observations/soil_moisture/regridded_HydroJULES/52007_soil_moisture_ref_2015_2017.nc
# [########################################] | 100% Completed | 14.7s
# 49004 finished: /gpfs/work1/0/wtrcycle/users/jaerts/model_refinement_pub/observations/soil_moisture/regridded_HydroJULES/49004_soil_moisture_ref_2015_2017.nc
# [########################################] | 100% Completed | 15.7s
# 107001 finished: /gpfs/work1/0/wtrcycle/users/jaerts/model_refinement_pub/observations/soil_moisture/regridded_HydroJULES/107001_soil_moisture_ref_2015_2017.nc
# [#####################                   ] | 54% Completed | 13.8ss
# 28033 finished: /gpfs/work1/0/wtrcycle/users/jaerts/model_refinement_pub/observations/soil_moisture/regridded_HydroJULES/28033_soil_moisture_ref_2015_2017.nc
# [########################################] | 100% Completed | 14.4s
# 38021 finished: /gpfs/work1/0/wtrcycle/users/jaerts/model_refinement_pub/observations/soil_moisture/regridded_HydroJULES/38021_soil_moisture_ref_2015_2017.nc
# [########################################] | 100% Completed | 27.8s
# 64002 finished: /gpfs/work1/0/wtrcycle/users/jaerts/model_refinement_pub/observations/soil_moisture/regridded_HydroJULES/64002_soil_moisture_ref_2015_2017.nc
# [########################################] | 100% Completed | 14.9s
# 28115 finished: /gpfs/work1/0/wtrcycle/users/jaerts/model_refinement_pub/observations/soil_moisture/regridded_HydroJULES/28115_soil_moisture_ref_2015_2017.nc
# [########################################] | 100% Completed | 14.7s
# 38007 finished: /gpfs/work1/0/wtrcycle/users/jaerts/model_refinement_pub/observations/soil_moisture/regridded_HydroJULES/38007_soil_moisture_ref_2015_2017.nc
# [########################################] | 100% Completed | 28.0s
# 26006 finished: /gpfs/work1/0/wtrcycle/users/jaerts/model_refinement_pub/observations/soil_moisture/regridded_HydroJULES/26006_soil_moisture_ref_2015_2017.nc
# [########################################] | 100% Completed | 26.6s
# [                                        ] | 0% Completed | 15.6ss89002 finished: /gpfs/work1/0/wtrcycle/users/jaerts/model_refinement_pub/observations/soil_moisture/regridded_HydroJULES/89002_soil_moisture_ref_2015_2017.nc
# [########################################] | 100% Completed | 28.3s
# 30012 finished: /gpfs/work1/0/wtrcycle/users/jaerts/model_refinement_pub/observations/soil_moisture/regridded_HydroJULES/30012_soil_moisture_ref_2015_2017.nc
# [########################################] | 100% Completed | 28.4s
# 39015 finished: /gpfs/work1/0/wtrcycle/users/jaerts/model_refinement_pub/observations/soil_moisture/regridded_HydroJULES/39015_soil_moisture_ref_2015_2017.nc
# [########################################] | 100% Completed | 14.9s
# 7006 finished: /gpfs/work1/0/wtrcycle/users/jaerts/model_refinement_pub/observations/soil_moisture/regridded_HydroJULES/7006_soil_moisture_ref_2015_2017.nc
# [########################################] | 100% Completed | 14.6s
# 18018 finished: /gpfs/work1/0/wtrcycle/users/jaerts/model_refinement_pub/observations/soil_moisture/regridded_HydroJULES/18018_soil_moisture_ref_2015_2017.nc
# [                                        ] | 0% Completed |  0.0s0s
# 37031 finished: /gpfs/work1/0/wtrcycle/users/jaerts/model_refinement_pub/observations/soil_moisture/regridded_HydroJULES/37031_soil_moisture_ref_2015_2017.nc
# [########################################] | 100% Completed | 28.1s
# 28072 finished: /gpfs/work1/0/wtrcycle/users/jaerts/model_refinement_pub/observations/soil_moisture/regridded_HydroJULES/28072_soil_moisture_ref_2015_2017.nc
# [########################################] | 100% Completed | 14.7s
# 12009 finished: /gpfs/work1/0/wtrcycle/users/jaerts/model_refinement_pub/observations/soil_moisture/regridded_HydroJULES/12009_soil_moisture_ref_2015_2017.nc
# [########################################] | 100% Completed | 15.1s
# 48004 finished: /gpfs/work1/0/wtrcycle/users/jaerts/model_refinement_pub/observations/soil_moisture/regridded_HydroJULES/48004_soil_moisture_ref_2015_2017.nc
# [########################################] | 100% Completed | 14.4s
# 44006 finished: /gpfs/work1/0/wtrcycle/users/jaerts/model_refinement_pub/observations/soil_moisture/regridded_HydroJULES/44006_soil_moisture_ref_2015_2017.nc
# [########################################] | 100% Completed | 28.1s
# 47014 finished: /gpfs/work1/0/wtrcycle/users/jaerts/model_refinement_pub/observations/soil_moisture/regridded_HydroJULES/47014_soil_moisture_ref_2015_2017.nc
# [########################################] | 100% Completed | 28.4s
# 50008 finished: /gpfs/work1/0/wtrcycle/users/jaerts/model_refinement_pub/observations/soil_moisture/regridded_HydroJULES/50008_soil_moisture_ref_2015_2017.nc
# [########################################] | 100% Completed | 14.8s
# 44011 finished: /gpfs/work1/0/wtrcycle/users/jaerts/model_refinement_pub/observations/soil_moisture/regridded_HydroJULES/44011_soil_moisture_ref_2015_2017.nc
# [########################################] | 100% Completed | 15.0s
# 17015 finished: /gpfs/work1/0/wtrcycle/users/jaerts/model_refinement_pub/observations/soil_moisture/regridded_HydroJULES/17015_soil_moisture_ref_2015_2017.nc
# [########################################] | 100% Completed | 14.8s
# 27038 finished: /gpfs/work1/0/wtrcycle/users/jaerts/model_refinement_pub/observations/soil_moisture/regridded_HydroJULES/27038_soil_moisture_ref_2015_2017.nc
# [########################################] | 100% Completed | 27.8s
# 58008 finished: /gpfs/work1/0/wtrcycle/users/jaerts/model_refinement_pub/observations/soil_moisture/regridded_HydroJULES/58008_soil_moisture_ref_2015_2017.nc
# [########################################] | 100% Completed | 14.5s
# 33032 finished: /gpfs/work1/0/wtrcycle/users/jaerts/model_refinement_pub/observations/soil_moisture/regridded_HydroJULES/33032_soil_moisture_ref_2015_2017.nc
# [########################################] | 100% Completed | 14.3s
# 46005 finished: /gpfs/work1/0/wtrcycle/users/jaerts/model_refinement_pub/observations/soil_moisture/regridded_HydroJULES/46005_soil_moisture_ref_2015_2017.nc
# [########################################] | 100% Completed | 14.5s
# 52015 finished: /gpfs/work1/0/wtrcycle/users/jaerts/model_refinement_pub/observations/soil_moisture/regridded_HydroJULES/52015_soil_moisture_ref_2015_2017.nc
# [########################################] | 100% Completed | 14.5s
# 27051 finished: /gpfs/work1/0/wtrcycle/users/jaerts/model_refinement_pub/observations/soil_moisture/regridded_HydroJULES/27051_soil_moisture_ref_2015_2017.nc
# [########################################] | 100% Completed | 27.9s
# 37011 finished: /gpfs/work1/0/wtrcycle/users/jaerts/model_refinement_pub/observations/soil_moisture/regridded_HydroJULES/37011_soil_moisture_ref_2015_2017.nc
# [########################################] | 100% Completed | 14.3s
# 25021 finished: /gpfs/work1/0/wtrcycle/users/jaerts/model_refinement_pub/observations/soil_moisture/regridded_HydroJULES/25021_soil_moisture_ref_2015_2017.nc
# [########################################] | 100% Completed | 14.5s
# 84016 finished: /gpfs/work1/0/wtrcycle/users/jaerts/model_refinement_pub/observations/soil_moisture/regridded_HydroJULES/84016_soil_moisture_ref_2015_2017.nc
# [########################################] | 100% Completed | 14.3s
# 39054 finished: /gpfs/work1/0/wtrcycle/users/jaerts/model_refinement_pub/observations/soil_moisture/regridded_HydroJULES/39054_soil_moisture_ref_2015_2017.nc
# [########################################] | 100% Completed | 26.0s
# [####                                    ] | 10% Completed | 11.4s54022 finished: /gpfs/work1/0/wtrcycle/users/jaerts/model_refinement_pub/observations/soil_moisture/regridded_HydroJULES/54022_soil_moisture_ref_2015_2017.nc
# [########################################] | 100% Completed | 14.7s
# 88001 finished: /gpfs/work1/0/wtrcycle/users/jaerts/model_refinement_pub/observations/soil_moisture/regridded_HydroJULES/88001_soil_moisture_ref_2015_2017.nc
# [########################################] | 100% Completed | 14.5s
# 39120 finished: /gpfs/work1/0/wtrcycle/users/jaerts/model_refinement_pub/observations/soil_moisture/regridded_HydroJULES/39120_soil_moisture_ref_2015_2017.nc
# [########################################] | 100% Completed | 14.6s
# 40020 finished: /gpfs/work1/0/wtrcycle/users/jaerts/model_refinement_pub/observations/soil_moisture/regridded_HydroJULES/40020_soil_moisture_ref_2015_2017.nc
# [########################################] | 100% Completed | 15.1s
# 18014 finished: /gpfs/work1/0/wtrcycle/users/jaerts/model_refinement_pub/observations/soil_moisture/regridded_HydroJULES/18014_soil_moisture_ref_2015_2017.nc
# [########################################] | 100% Completed | 31.2s
# 55008 finished: /gpfs/work1/0/wtrcycle/users/jaerts/model_refinement_pub/observations/soil_moisture/regridded_HydroJULES/55008_soil_moisture_ref_2015_2017.nc
# [########################################] | 100% Completed | 14.8s
# 41022 finished: /gpfs/work1/0/wtrcycle/users/jaerts/model_refinement_pub/observations/soil_moisture/regridded_HydroJULES
soil_moisture_ref_2015_2017.nc
# [########################################] | 100% Completed | 14.2s
# 30011 finished: /gpfs/work1/0/wtrcycle/users/jaerts/model_refinement_pub/observations/soil_moisture/regridded_HydroJULES/30011_soil_moisture_ref_2015_2017.nc
# [########################################] | 100% Completed | 14.6s
# 47005 finished: /gpfs/work1/0/wtrcycle/users/jaerts/model_refinement_pub/observations/soil_moisture/regridded_HydroJULES/47005_soil_moisture_ref_2015_2017.nc
# [########################################] | 100% Completed | 14.4s
# 34012 finished: /gpfs/work1/0/wtrcycle/users/jaerts/model_refinement_pub/observations/soil_moisture/regridded_HydroJULES/34012_soil_moisture_ref_2015_2017.nc
# [########################################] | 100% Completed | 14.3s
# 58001 finished: /gpfs/work1/0/wtrcycle/users/jaerts/model_refinement_pub/observations/soil_moisture/regridded_HydroJULES/58001_soil_moisture_ref_2015_2017.nc
# [########################################] | 100% Completed | 14.8s
# 15021 finished: /gpfs/work1/0/wtrcycle/users/jaerts/model_refinement_pub/observations/soil_moisture/regridded_HydroJULES/15021_soil_moisture_ref_2015_2017.nc
# [########################################] | 100% Completed | 14.6s
# 78004 finished: /gpfs/work1/0/wtrcycle/users/jaerts/model_refinement_pub/observations/soil_moisture/regridded_HydroJULES/78004_soil_moisture_ref_2015_2017.nc
# [########################################] | 100% Completed | 27.7s
# 33029 finished: /gpfs/work1/0/wtrcycle/users/jaerts/model_refinement_pub/observations/soil_moisture/regridded_HydroJULES/33029_soil_moisture_ref_2015_2017.nc
# [########################################] | 100% Completed | 14.9s
# 34005 finished: /gpfs/work1/0/wtrcycle/users/jaerts/model_refinement_pub/observations/soil_moisture/regridded_HydroJULES/34005_soil_moisture_ref_2015_2017.nc
# [########################################] | 100% Completed | 14.6s
# 55025 finished: /gpfs/work1/0/wtrcycle/users/jaerts/model_refinement_pub/observations/soil_moisture/regridded_HydroJULES/55025_soil_moisture_ref_2015_2017.nc
# [########################################] | 100% Completed | 15.2s
# 84017 finished: /gpfs/work1/0/wtrcycle/users/jaerts/model_refinement_pub/observations/soil_moisture/regridded_HydroJULES/84017_soil_moisture_ref_2015_2017.nc
# [########################################] | 100% Completed | 15.1s
# 15014 finished: /gpfs/work1/0/wtrcycle/users/jaerts/model_refinement_pub/observations/soil_moisture/regridded_HydroJULES/15014_soil_moisture_ref_2015_2017.nc
# [########################################] | 100% Completed | 14.6s
# 54063 finished: /gpfs/work1/0/wtrcycle/users/jaerts/model_refinement_pub/observations/soil_moisture/regridded_HydroJULES/54063_soil_moisture_ref_2015_2017.nc
# [########################################] | 100% Completed | 15.1s
# 89007 finished: /gpfs/work1/0/wtrcycle/users/jaerts/model_refinement_pub/observations/soil_moisture/regridded_HydroJULES/89007_soil_moisture_ref_2015_2017.nc
# [########################################] | 100% Completed | 14.6s
# 57004 finished: /gpfs/work1/0/wtrcycle/users/jaerts/model_refinement_pub/observations/soil_moisture/regridded_HydroJULES/57004_soil_moisture_ref_2015_2017.nc
# [########################################] | 100% Completed | 15.1s
# 52010 finished: /gpfs/work1/0/wtrcycle/users/jaerts/model_refinement_pub/observations/soil_moisture/regridded_HydroJULES/52010_soil_moisture_ref_2015_2017.nc
# [########################################] | 100% Completed | 14.7s
# 53028 finished: /gpfs/work1/0/wtrcycle/users/jaerts/model_refinement_pub/observations/soil_moisture/regridded_HydroJULES/53028_soil_moisture_ref_2015_2017.nc
# [########################################] | 100% Completed | 14.4s
# 77004 finished: /gpfs/work1/0/wtrcycle/users/jaerts/model_refinement_pub/observations/soil_moisture/regridded_HydroJULES/77004_soil_moisture_ref_2015_2017.nc
# [########################################] | 100% Completed | 14.7s
# 27023 finished: /gpfs/work1/0/wtrcycle/users/jaerts/model_refinement_pub/observations/soil_moisture/regridded_HydroJULES/27023_soil_moisture_ref_2015_2017.nc
# [########################################] | 100% Completed | 14.4s
# 4006 finished: /gpfs/work1/0/wtrcycle/users/jaerts/model_refinement_pub/observations/soil_moisture/regridded_HydroJULES/4006_soil_moisture_ref_2015_2017.nc
# [########################################] | 100% Completed | 15.6s
# 34011 finished: /gpfs/work1/0/wtrcycle/users/jaerts/model_refinement_pub/observations/soil_moisture/regridded_HydroJULES/34011_soil_moisture_ref_2015_2017.nc
# [########################################] | 100% Completed | 14.7s
# 68004 finished: /gpfs/work1/0/wtrcycle/users/jaerts/model_refinement_pub/observations/soil_moisture/regridded_HydroJULES/68004_soil_moisture_ref_2015_2017.nc
# ...
# [#####################                   ] | 54% Completed | 14.0ss
# 81007 finished: /gpfs/work1/0/wtrcycle/users/jaerts/model_refinement_pub/observations/soil_moisture/regridded_HydroJULES/81007_soil_moisture_ref_2015_2017.nc
# [########################################] | 100% Completed | 28.0s
# 42001 finished: /gpfs/work1/0/wtrcycle/users/jaerts/model_refinement_pub/observations/soil_moisture/regridded_HydroJULES/42001_soil_moisture_ref_2015_2017.nc
# [########################################] | 100% Completed | 15.0s
# 83003 finished: /gpfs/work1/0/wtrcycle/users/jaerts/model_refinement_pub/observations/soil_moisture/regridded_HydroJULES/83003_soil_moisture_ref_2015_2017.nc
# [########################################] | 100% Completed | 15.0s
# 34002 finished: /gpfs/work1/0/wtrcycle/users/jaerts/model_refinement_pub/observations/soil_moisture/regridded_HydroJULES/34002_soil_moisture_ref_2015_2017.nc
# [########################################] | 100% Completed | 14.8s
# 47008 finished: /gpfs/work1/0/wtrcycle/users/jaerts/model_refinement_pub/observations/soil_moisture/regridded_HydroJULES/47008_soil_moisture_ref_2015_2017.nc
# [########################################] | 100% Completed | 15.1s
# [                                        ] | 0% Completed |  2.0sent_pub/observations/soil_moisture/regridded_HydroJULES/52004_soil_moisture_ref_2015_2017.nc
# [########################################] | 100% Completed | 27.7s
# 42027 finished: /gpfs/work1/0/wtrcycle/users/jaerts/model_refinement_pub/observations/soil_moisture/regridded_HydroJULES/42027_soil_moisture_ref_2015_2017.nc
# [########################################] | 100% Completed | 14.4s
# 38030 finished: /gpfs/work1/0/wtrcycle/users/jaerts/model_refinement_pub/observations/soil_moisture/regridded_HydroJULES/38030_soil_moisture_ref_2015_2017.nc
# [########################################] | 100% Completed | 14.5s
# 53006 finished: /gpfs/work1/0/wtrcycle/users/jaerts/model_refinement_pub/observations/soil_moisture/regridded_HydroJULES/53006_soil_moisture_ref_2015_2017.nc
# [########################################] | 100% Completed | 14.2s
# 43014 finished: /gpfs/work1/0/wtrcycle/users/jaerts/model_refinement_pub/observations/soil_moisture/regridded_HydroJULES/43014_soil_moisture_ref_2015_2017.nc
# [########################################] | 100% Completed | 15.1s
# 74007 finished: /gpfs/work1/0/wtrcycle/users/jaerts/model_refinement_pub/observations/soil_moisture/regridded_HydroJULES/74007_soil_moisture_ref_2015_2017.nc
# [#####################                   ] | 54% Completed | 14.0ss
# 74001 finished: /gpfs/work1/0/wtrcycle/users/jaerts/model_refinement_pub/observations/soil_moisture/regridded_HydroJULES/74001_soil_moisture_ref_2015_2017.nc
# [########################################] | 100% Completed | 14.6s
# 18002 finished: /gpfs/work1/0/wtrcycle/users/jaerts/model_refinement_pub/observations/soil_moisture/regridded_HydroJULES/18002_soil_moisture_ref_2015_2017.nc
# [########################################] | 100% Completed | 14.3s
# 33007 finished: /gpfs/work1/0/wtrcycle/users/jaerts/model_refinement_pub/observations/soil_moisture/regridded_HydroJULES/33007_soil_moisture_ref_2015_2017.nc
# [########################################] | 100% Completed | 14.5s
# 43017 finished: /gpfs/work1/0/wtrcycle/users/jaerts/model_refinement_pub/observations/soil_moisture/regridded_HydroJULES/43017_soil_moisture_ref_2015_2017.nc
# [########################################] | 100% Completed | 24.0s
# [#                                       ] | 4% Completed |  9.5s41025 finished: /gpfs/work1/0/wtrcycle/users/jaerts/model_refinement_pub/observations/soil_moisture/regridded_HydroJULES/41025_soil_moisture_ref_2015_2017.nc
# [########################################] | 100% Completed | 14.7s
# 40016 finished: /gpfs/work1/0/wtrcycle/users/jaerts/model_refinement_pub/observations/soil_moisture/regridded_HydroJULES/40016_soil_moisture_ref_2015_2017.nc
# [########################################] | 100% Completed | 14.7s
# 24005 finished: /gpfs/work1/0/wtrcycle/users/jaerts/model_refinement_pub/observations/soil_moisture/regridded_HydroJULES/24005_soil_moisture_ref_2015_2017.nc
# [########################################] | 100% Completed | 14.5s
# 75004 finished: /gpfs/work1/0/wtrcycle/users/jaerts/model_refinement_pub/observations/soil_moisture/regridded_HydroJULES/75004_soil_moisture_ref_2015_2017.nc
# [########################################] | 100% Completed | 14.5s
# 28046 finished: /gpfs/work1/0/wtrcycle/users/jaerts/model_refinement_pub/observations/soil_moisture/regridded_HydroJULES/28046_soil_moisture_ref_2015_2017.nc
# [########################################] | 100% Completed | 14.7s
# 27064 finished: /gpfs/work1/0/wtrcycle/users/jaerts/model_refinement_pub/observations/soil_moisture/regridded_HydroJULES/27064_soil_moisture_ref_2015_2017.nc
# [########################################] | 100% Completed | 14.6s
# 14002 finished: /gpfs/work1/0/wtrcycle/users/jaerts/model_refinement_pub/observations/soil_moisture/regridded_HydroJULES/14002_soil_moisture_ref_2015_2017.nc
# [#####################                   ] | 52% Completed | 13.9ss
# 71014 finished: /gpfs/work1/0/wtrcycle/users/jaerts/model_refinement_pub/observations/soil_moisture/regridded_HydroJULES/71014_soil_moisture_ref_2015_2017.nc
# [########################################] | 100% Completed | 14.8s
# 55032 finished: /gpfs/work1/0/wtrcycle/users/jaerts/model_refinement_pub/observations/soil_moisture/regridded_HydroJULES/55032_soil_moisture_ref_2015_2017.nc
# [########################################] | 100% Completed | 16.4s
# 12006 finished: /gpfs/work1/0/wtrcycle/users/jaerts/model_refinement_pub/observations/soil_moisture/regridded_HydroJULES/12006_soil_moisture_ref_2015_2017.nc
# [########################################] | 100% Completed | 14.7s
# 52011 finished: /gpfs/work1/0/wtrcycle/users/jaerts/model_refinement_pub/observations/soil_moisture/regridded_HydroJULES/52011_soil_moisture_ref_2015_2017.nc
# [########################################] | 100% Completed | 14.7s
# 26003 finished: /gpfs/work1/0/wtrcycle/users/jaerts/model_refinement_pub/observations/soil_moisture/regridded_HydroJULES/26003_soil_moisture_ref_2015_2017.nc
# [########################################] | 100% Completed | 14.8s
# 39037 finished: /gpfs/work1/0/wtrcycle/users/jaerts/model_refinement_pub/observations/soil_moisture/regridded_HydroJULES/39037_soil_moisture_ref_2015_2017.nc
# [########################################] | 100% Completed | 14.8s
# 25020 finished: /gpfs/work1/0/wtrcycle/users/jaerts/model_refinement_pub/observations/soil_moisture/regridded_HydroJULES/25020_soil_moisture_ref_2015_2017.nc
# [########################################] | 100% Completed | 14.5s
# 43018 finished: /gpfs/work1/0/wtrcycle/users/jaerts/model_refinement_pub/observations/soil_moisture/regridded_HydroJULES/43018_soil_moisture_ref_2015_2017.nc
# [########################################] | 100% Completed | 15.1s
# [                                        ] | 0% Completed |  1.6s28056 finished: /gpfs/work1/0/wtrcycle/users/jaerts/model_refinement_pub/observations/soil_moisture/regridded_HydroJULES/28056_soil_moisture_ref_2015_2017.nc
# [########################################] | 100% Completed | 14.5s
# 54044 finished: /gpfs/work1/0/wtrcycle/users/jaerts/model_refinement_pub/observations/soil_moisture/regridded_HydroJULES/54044_soil_moisture_ref_2015_2017.nc
# [########################################] | 100% Completed | 14.3s
# 40018 finished: /gpfs/work1/0/wtrcycle/users/jaerts/model_refinement_pub/observations/soil_moisture/regridded_HydroJULES/40018_soil_moisture_ref_2015_2017.nc
# [########################################] | 100% Completed | 14.3s
# 84022 finished: /gpfs/work1/0/wtrcycle/users/jaerts/model_refinement_pub/observations/soil_moisture/regridded_HydroJULES/84022_soil_moisture_ref_2015_2017.nc
# [########################################] | 100% Completed | 14.4s
# 9004 finished: /gpfs/work1/0/wtrcycle/users/jaerts/model_refinement_pub/observations/soil_moisture/regridded_HydroJULES/9004_soil_moisture_ref_2015_2017.nc
# [########################################] | 100% Completed | 14.5s
# [                                        ] | 0% Completed |  0.5s54048 finished: /gpfs/work1/0/wtrcycle/users/jaerts/model_refinement_pub/observations/soil_moisture/regridded_HydroJULES/54048_soil_moisture_ref_2015_2017.nc
# [########################################] | 100% Completed | 14.7s
# 54052 finished: /gpfs/work1/0/wtrcycle/users/jaerts/model_refinement_pub/observations/soil_moisture/regridded_HydroJULES/54052_soil_moisture_ref_2015_2017.nc
# [########################################] | 100% Completed | 14.5s
# 53005 finished: /gpfs/work1/0/wtrcycle/users/jaerts/model_refinement_pub/observations/soil_moisture/regridded_HydroJULES/53005_soil_moisture_ref_2015_2017.nc
# [########################################] | 100% Completed | 14.7s
# 17001 finished: /gpfs/work1/0/wtrcycle/users/jaerts/model_refinement_pub/observations/soil_moisture/regridded_HydroJULES/17001_soil_moisture_ref_2015_2017.nc
# [########################################] | 100% Completed | 14.5s
# 20003 finished: /gpfs/work1/0/wtrcycle/users/jaerts/model_refinement_pub/observations/soil_moisture/regridded_HydroJULES/20003_soil_moisture_ref_2015_2017.nc
# [########################################] | 100% Completed | 28.5s
# 85003 finished: /gpfs/work1/0/wtrcycle/users/jaerts/model_refinement_pub/observations/soil_moisture/regridded_HydroJULES/85003_soil_moisture_ref_2015_2017.nc
# [########################################] | 100% Completed | 15.3s
# 84030 finished: /gpfs/work1/0/wtrcycle/users/jaerts/model_refinement_pub/observations/soil_moisture/regridded_HydroJULES/84030_soil_moisture_ref_2015_2017.nc
# [########################################] | 100% Completed | 14.9s
# 79004 finished: /gpfs/work1/0/wtrcycle/users/jaerts/model_refinement_pub/observations/soil_moisture/regridded_HydroJULES/79004_soil_moisture_ref_2015_2017.nc
# [########################################] | 100% Completed | 14.8s
# 13004 finished: /gpfs/work1/0/wtrcycle/users/jaerts/model_refinement_pub/observations/soil_moisture/regridded_HydroJULES/13004_soil_moisture_ref_2015_2017.nc
# [########################################] | 100% Completed | 14.5s
# 28023 finished: /gpfs/work1/0/wtrcycle/users/jaerts/model_refinement_pub/observations/soil_moisture/regridded_HydroJULES/28023_soil_moisture_ref_2015_2017.nc
# [########################################] | 100% Completed | 28.3s
# 56013 finished: /gpfs/work1/0/wtrcycle/users/jaerts/model_refinement_pub/observations/soil_moisture/regridded_HydroJULES/56013_soil_moisture_ref_2015_2017.nc
# [########################################] | 100% Completed | 14.9s
# 57006 finished: /gpfs/work1/0/wtrcycle/users/jaerts/model_refinement_pub/observations/soil_moisture/regridded_HydroJULES/57006_soil_moisture_ref_2015_2017.nc
# [########################################] | 100% Completed | 14.9s
# 37020 finished: /gpfs/work1/0/wtrcycle/users/jaerts/model_refinement_pub/observations/soil_moisture/regridded_HydroJULES/37020_soil_moisture_ref_2015_2017.nc
# [########################################] | 100% Completed | 15.3s
# [                                        ] | 0% Completed |  1.4s73011 finished: /gpfs/work1/0/wtrcycle/users/jaerts/model_refinement_pub/observations/soil_moisture/regridded_HydroJULES/73011_soil_moisture_ref_2015_2017.nc
# [########################################] | 100% Completed | 14.6s
# 28048 finished: /gpfs/work1/0/wtrcycle/users/jaerts/model_refinement_pub/observations/soil_moisture/regridded_HydroJULES/28048_soil_moisture_ref_2015_2017.nc
# [########################################] | 100% Completed | 28.3s
# 40022 finished: /gpfs/work1/0/wtrcycle/users/jaerts/model_refinement_pub/observations/soil_moisture/regridded_HydroJULES/40022_soil_moisture_ref_2015_2017.nc
# [########################################] | 100% Completed | 14.4s
# [########################################] | 100% Completed |  0.2s
# [                                        ] | 0% Completed |  0.1s33012 finished: /gpfs/work1/0/wtrcycle/users/jaerts/model_refinement_pub/observations/soil_moisture/regridded_HydroJULES/33012_soil_moisture_ref_2015_2017.nc
# [########################################] | 100% Completed |  0.2s
# [########################################] | 100% Completed |  0.2s
# [########################################] | 100% Completed |  0.2s
# [########################################] | 100% Completed |  0.2s
# [########################################] | 100% Completed |  0.2s
# [########################################] | 100% Completed |  0.2s
# [########################################] | 100% Completed | 14.1s
# [########################################] | 100% Completed |  0.3s
# [########################################] | 100% Completed |  0.3s
# [########################################] | 100% Completed | 14.9s
# 41019 finished: /gpfs/work1/0/wtrcycle/users/jaerts/model_refinement_pub/observations/soil_moisture/regridded_HydroJULES/41019_soil_moisture_ref_2015_2017.nc
# [########################################] | 100% Completed |  0.2s
# [########################################] | 100% Completed |  0.2s
# [########################################] | 100% Completed |  0.2s
# [########################################] | 100% Completed |  0.2s
# [########################################] | 100% Completed |  0.2s
# [########################################] | 100% Completed |  0.2s
# [########################################] | 100% Completed |  0.2s
# [########################################] | 100% Completed |  0.2s
# [########################################] | 100% Completed |  0.2s
# [########################################] | 100% Completed |  0.2s
# [########################################] | 100% Completed |  0.2s
# [########################################] | 100% Completed |  0.2s
# [########################################] | 100% Completed |  0.2s
# [########################################] | 100% Completed |  0.2s
# [########################################] | 100% Completed | 14.7s
# 33028 finished: /gpfs/work1/0/wtrcycle/users/jaerts/model_refinement_pub/observations/soil_moisture/regridded_HydroJULES/33028_soil_moisture_ref_2015_2017.nc
# [########################################] | 100% Completed | 14.4s
# 41005 finished: /gpfs/work1/0/wtrcycle/users/jaerts/model_refinement_pub/observations/soil_moisture/regridded_HydroJULES/41005_soil_moisture_ref_2015_2017.nc
# [########################################] | 100% Completed | 14.5s
# 38029 finished: /gpfs/work1/0/wtrcycle/users/jaerts/model_refinement_pub/observations/soil_moisture/regridded_HydroJULES/38029_soil_moisture_ref_2015_2017.nc
# [########################################] | 100% Completed | 14.2s
# 69012 finished: /gpfs/work1/0/wtrcycle/users/jaerts/model_refinement_pub/observations/soil_moisture/regridded_HydroJULES/69012_soil_moisture_ref_2015_2017.nc
# [########################################] | 100% Completed | 14.3s
# 42008 finished: /gpfs/work1/0/wtrcycle/users/jaerts/model_refinement_pub/observations/soil_moisture/regridded_HydroJULES/42008_soil_moisture_ref_2015_2017.nc
# [########################################] | 100% Completed | 14.8s
# 39042 finished: /gpfs/work1/0/wtrcycle/users/jaerts/model_refinement_pub/observations/soil_moisture/regridded_HydroJULES/39042_soil_moisture_ref_2015_2017.nc
# [########################################] | 100% Completed | 14.5s
# 38003 finished: /gpfs/work1/0/wtrcycle/users/jaerts/model_refinement_pub/observations/soil_moisture/regridded_HydroJULES/38003_soil_moisture_ref_2015_2017.nc
# Exception ignored in: <function WeakSet.__init__.<locals>._remove at 0x150bc46755a0>
# Traceback (most recent call last):
#   File "/home/jaerts/miniconda3/envs/wflow_state_flux/lib/python3.10/_weakrefset.py", line 39, in _remove
#     def _remove(item, selfref=ref(self)):
# KeyboardInterrupt:
#
# KeyboardInterrupt
# [                                        ] | 0% Completed |  0.0ss
