# %% [markdown]
# ## Create reference evapotranspiration time series (FLUXCOM)

# %% [markdown]
# Unit Conversion is based on: https://earthscience.stackexchange.com/questions/20733/fluxnet15-how-to-convert-latent-heat-flux-to-actual-evapotranspiration

# %%
import warnings
warnings.filterwarnings("ignore", category=UserWarning)
warnings.filterwarnings("ignore", category=DeprecationWarning)

# %%
from glob import glob
from pathlib import Path

import os
import iris
import xarray as xr
import pandas as pd
from esmvalcore.preprocessor import regrid
from pathos.threading import ThreadPool as Pool
from dask.diagnostics import ProgressBar

# %% [markdown]
# ## Set Paths

# %%
# Set Paths
ROOT = Path('/gpfs/work1/0/wtrcycle/users/jaerts/model_refinement_pub/')
AUXDIR = Path(f"{ROOT}/aux_data/")
OBSDIR = Path(f"{ROOT}/observations/")
MODELS = Path(f'{ROOT}/model_parameters/wflow_sbm/')
OUTPUT = Path(f'{OBSDIR}/evaporation/regridded_FLUXCOM/')

# %% [markdown]
# ## Config

# %%
# Get available basin IDs wflow_sbm
basin_dirs = glob(f'{MODELS}/*')
basin_ids = [s.split('/')[-1] for s in basin_dirs]
basin_ids.sort()

# Amount of available cores
cores_available = 1

# %% [markdown]
# ## Preprocess function

# %%
def prep_observations(basin_id):
    print(basin_id)
    # Set basin directory
    BASINDIR = f'{MODELS}/{basin_id}/'
    
    # Open netCDF file as an example grid from the model directory
    cube_example = iris.load(f'{BASINDIR}/staticmaps.nc')[1]

    # Guess bounds   
    cube_example.coord('y').guess_bounds()
    cube_example.coord('x').guess_bounds()

    # Rename Coords
    cube_example.coord('y').rename('latitude')
    cube_example.coord('x').rename('longitude')

    cube_example.coord('latitude').units = 'degrees'
    cube_example.coord('longitude').units = 'degrees'
    
    # Load observation netCDF files
    files = glob(f'{OBSDIR}/evaporation/FLUXCOM/*.nc')
    
    def edit_attributes(cube, field, filename):
        cube.attributes.pop('History', 'none')

    cubes_obs = iris.load(files, 'latent heat', callback=edit_attributes)
    cube_obs = cubes_obs.concatenate_cube()
    
    # Regrid observation cube
    cube_out = regrid(cube_obs, cube_example, scheme='area_weighted')
    
    # Create obs dataset
    da = xr.DataArray.from_iris(cube_out)

    # Create mask dataset
    mask = xr.open_dataset(f'{BASINDIR}/staticmaps.nc').mask
    mask = mask.rename({'y':'latitude','x':'longitude'})

    # Convert unit to mm/time
    da = da / 2.45

    # Apply mask
    da = da.where(mask>0)
    
    # Calculate time series
    da = da.mean(['latitude','longitude'])
    da = da.chunk(chunks='auto')
    da = da.drop('spatial_ref')
    
    # Output filename
    output_fname = f'{OUTPUT}/{basin_id}_FLUXCOM_evaporation_ref_2008_2015.nc'

    # Save to netcdf
    write_job = da.to_netcdf(output_fname, compute=False)
    with ProgressBar():
        write_job.compute()
        
    return print(f'{basin_id} finished: {output_fname}')

# %% [markdown]
# ## Parallel Run Function

# %%
def parallel_run(
    basin_ids,
    threads=cores_available,
    ):
    
    # Set number of threads (cores) used for parallel run and map threads
    if threads is None:
        pool = Pool()
    else:
        pool = Pool(nodes=threads)
    # Run parallel models
    pool.map(
        prep_observations,
        basin_ids,
        )
    return

# %% [markdown]
# ## Sort basins by size

# %%
# Sort by basin size
def sort_basin_ids_by_size(basin_ids):
    sizes = []
    for basin_id in basin_ids:
        size = os.path.getsize(f'{MODELS}/{basin_id}/staticmaps.nc')
        sizes.append(size)

    df = pd.DataFrame()
    df['basin_id'] = basin_ids
    df['size'] = sizes
    df = df.sort_values('size')

    basin_ids = df.basin_id.to_list()
    
    return basin_ids

basin_ids_sorted = sort_basin_ids_by_size(basin_ids)

# %% [markdown]
# # Run parallel function

# %%
# Run function
parallel_run(basin_ids_sorted)
# Out:
# 80005
# [########################################] | 100% Completed | 48.5s
# 80005 finished: /gpfs/work1/0/wtrcycle/users/jaerts/model_refinement_pub/observations/evaporation/regridded_FLUXCOM/80005_FLUXCOM_evaporation_ref_2008_2015.nc
# 31023
# [########################################] | 100% Completed | 50.9s
# 31023 finished: /gpfs/work1/0/wtrcycle/users/jaerts/model_refinement_pub/observations/evaporation/regridded_FLUXCOM/31023_FLUXCOM_evaporation_ref_2008_2015.nc
# 80004
# [########################################] | 100% Completed | 51.4s
# 80004 finished: /gpfs/work1/0/wtrcycle/users/jaerts/model_refinement_pub/observations/evaporation/regridded_FLUXCOM/80004_FLUXCOM_evaporation_ref_2008_2015.nc
# 80003
# [########################################] | 100% Completed | 50.2s
# 80003 finished: /gpfs/work1/0/wtrcycle/users/jaerts/model_refinement_pub/observations/evaporation/regridded_FLUXCOM/80003_FLUXCOM_evaporation_ref_2008_2015.nc
# 76011
# [########################################] | 100% Completed | 51.8s
# 76011 finished: /gpfs/work1/0/wtrcycle/users/jaerts/model_refinement_pub/observations/evaporation/regridded_FLUXCOM/76011_FLUXCOM_evaporation_ref_2008_2015.nc
# 39061
# [########################################] | 100% Completed | 50.1s
# 39061 finished: /gpfs/work1/0/wtrcycle/users/jaerts/model_refinement_pub/observations/evaporation/regridded_FLUXCOM/39061_FLUXCOM_evaporation_ref_2008_2015.nc
# 18017
# [########################################] | 100% Completed | 50.6s
# 18017 finished: /gpfs/work1/0/wtrcycle/users/jaerts/model_refinement_pub/observations/evaporation/regridded_FLUXCOM/18017_FLUXCOM_evaporation_ref_2008_2015.nc
# 37033
# [########################################] | 100% Completed | 50.5s
# 37033 finished: /gpfs/work1/0/wtrcycle/users/jaerts/model_refinement_pub/observations/evaporation/regridded_FLUXCOM/37033_FLUXCOM_evaporation_ref_2008_2015.nc
# 28033
# [########################################] | 100% Completed | 49.8s
# 28033 finished: /gpfs/work1/0/wtrcycle/users/jaerts/model_refinement_pub/observations/evaporation/regridded_FLUXCOM/28033_FLUXCOM_evaporation_ref_2008_2015.nc
# 26006
# [########################################] | 100% Completed | 48.8s
# 26006 finished: /gpfs/work1/0/wtrcycle/users/jaerts/model_refinement_pub/observations/evaporation/regridded_FLUXCOM/26006_FLUXCOM_evaporation_ref_2008_2015.nc
# 18018
# [########################################] | 100% Completed | 51.2s
# 18018 finished: /gpfs/work1/0/wtrcycle/users/jaerts/model_refinement_pub/observations/evaporation/regridded_FLUXCOM/18018_FLUXCOM_evaporation_ref_2008_2015.nc
# 44006
# [########################################] | 100% Completed | 48.9s
# 44006 finished: /gpfs/work1/0/wtrcycle/users/jaerts/model_refinement_pub/observations/evaporation/regridded_FLUXCOM/44006_FLUXCOM_evaporation_ref_2008_2015.nc
# 27038
# [########################################] | 100% Completed | 50.4s
# 27038 finished: /gpfs/work1/0/wtrcycle/users/jaerts/model_refinement_pub/observations/evaporation/regridded_FLUXCOM/27038_FLUXCOM_evaporation_ref_2008_2015.nc
# 27051
# [########################################] | 100% Completed | 50.0s
# 27051 finished: /gpfs/work1/0/wtrcycle/users/jaerts/model_refinement_pub/observations/evaporation/regridded_FLUXCOM/27051_FLUXCOM_evaporation_ref_2008_2015.nc
# 54022
# [########################################] | 100% Completed | 50.2s
# 54022 finished: /gpfs/work1/0/wtrcycle/users/jaerts/model_refinement_pub/observations/evaporation/regridded_FLUXCOM/54022_FLUXCOM_evaporation_ref_2008_2015.nc
# 55008
# [########################################] | 100% Completed | 50.8s
# 55008 finished: /gpfs/work1/0/wtrcycle/users/jaerts/model_refinement_pub/observations/evaporation/regridded_FLUXCOM/55008_FLUXCOM_evaporation_ref_2008_2015.nc
# 39036
# [########################################] | 100% Completed | 50.7s
# 39036 finished: /gpfs/work1/0/wtrcycle/users/jaerts/model_refinement_pub/observations/evaporation/regridded_FLUXCOM/39036_FLUXCOM_evaporation_ref_2008_2015.nc
# 25003
# [########################################] | 100% Completed | 49.6s
# 25003 finished: /gpfs/work1/0/wtrcycle/users/jaerts/model_refinement_pub/observations/evaporation/regridded_FLUXCOM/25003_FLUXCOM_evaporation_ref_2008_2015.nc
# 27047
# [########################################] | 100% Completed | 45.9s
# 27047 finished: /gpfs/work1/0/wtrcycle/users/jaerts/model_refinement_pub/observations/evaporation/regridded_FLUXCOM/27047_FLUXCOM_evaporation_ref_2008_2015.nc
# 65008
# [########################################] | 100% Completed | 34.1s
# 65008 finished: /gpfs/work1/0/wtrcycle/users/jaerts/model_refinement_pub/observations/evaporation/regridded_FLUXCOM/65008_FLUXCOM_evaporation_ref_2008_2015.nc
# 52016
# [########################################] | 100% Completed | 33.7s
# 52016 finished: /gpfs/work1/0/wtrcycle/users/jaerts/model_refinement_pub/observations/evaporation/regridded_FLUXCOM/52016_FLUXCOM_evaporation_ref_2008_2015.nc
# 58010
# [########################################] | 100% Completed | 34.9s
# 58010 finished: /gpfs/work1/0/wtrcycle/users/jaerts/model_refinement_pub/observations/evaporation/regridded_FLUXCOM/58010_FLUXCOM_evaporation_ref_2008_2015.nc
# 42017
# [########################################] | 100% Completed | 34.0s
# 42017 finished: /gpfs/work1/0/wtrcycle/users/jaerts/model_refinement_pub/observations/evaporation/regridded_FLUXCOM
 finished: /gpfs/work1/0/wtrcycle/users/jaerts/model_refinement_pub/observations/evaporation/regridded_FLUXCOM/39015_FLUXCOM_evaporation_ref_2008_2015.nc
# 12009
# [########################################] | 100% Completed | 33.7s
# 12009 finished: /gpfs/work1/0/wtrcycle/users/jaerts/model_refinement_pub/observations/evaporation/regridded_FLUXCOM/12009_FLUXCOM_evaporation_ref_2008_2015.nc
# 44011
# [########################################] | 100% Completed | 33.6s
# 44011 finished: /gpfs/work1/0/wtrcycle/users/jaerts/model_refinement_pub/observations/evaporation/regridded_FLUXCOM/44011_FLUXCOM_evaporation_ref_2008_2015.nc
# 46005
# [########################################] | 100% Completed | 34.2s
# 46005 finished: /gpfs/work1/0/wtrcycle/users/jaerts/model_refinement_pub/observations/evaporation/regridded_FLUXCOM/46005_FLUXCOM_evaporation_ref_2008_2015.nc
# 84016
# [########################################] | 100% Completed | 34.4s
# 84016 finished: /gpfs/work1/0/wtrcycle/users/jaerts/model_refinement_pub/observations/evaporation/regridded_FLUXCOM/84016_FLUXCOM_evaporation_ref_2008_2015.nc
# 40020
# [########################################] | 100% Completed | 33.5s
# 40020 finished: /gpfs/work1/0/wtrcycle/users/jaerts/model_refinement_pub/observations/evaporation/regridded_FLUXCOM/40020_FLUXCOM_evaporation_ref_2008_2015.nc
# 30015
# [########################################] | 100% Completed | 33.2s
# 30015 finished: /gpfs/work1/0/wtrcycle/users/jaerts/model_refinement_pub/observations/evaporation/regridded_FLUXCOM/30015_FLUXCOM_evaporation_ref_2008_2015.nc
# 85004
# [########################################] | 100% Completed | 33.4s
# 85004 finished: /gpfs/work1/0/wtrcycle/users/jaerts/model_refinement_pub/observations/evaporation/regridded_FLUXCOM/85004_FLUXCOM_evaporation_ref_2008_2015.nc
# 54025
# [########################################] | 100% Completed | 33.4s
# 54025 finished: /gpfs/work1/0/wtrcycle/users/jaerts/model_refinement_pub/observations/evaporation/regridded_FLUXCOM/54025_FLUXCOM_evaporation_ref_2008_2015.nc
# 19020
# [########################################] | 100% Completed | 33.4s
# 19020 finished: /gpfs/work1/0/wtrcycle/users/jaerts/model_refinement_pub/observations/evaporation/regridded_FLUXCOM/19020_FLUXCOM_evaporation_ref_2008_2015.nc
# 42011
# [########################################] | 100% Completed | 33.6s
# 42011 finished: /gpfs/work1/0/wtrcycle/users/jaerts/model_refinement_pub/observations/evaporation/regridded_FLUXCOM/42011_FLUXCOM_evaporation_ref_2008_2015.nc
# 63004
# [########################################] | 100% Completed | 34.3s
# 63004 finished: /gpfs/work1/0/wtrcycle/users/jaerts/model_refinement_pub/observations/evaporation/regridded_FLUXCOM/63004_FLUXCOM_evaporation_ref_2008_2015.nc
# 73015
# [########################################] | 100% Completed | 34.1s
# 73015 finished: /gpfs/work1/0/wtrcycle/users/jaerts/model_refinement_pub/observations/evaporation/regridded_FLUXCOM/73015_FLUXCOM_evaporation_ref_2008_2015.nc
# 47009
# [########################################] | 100% Completed | 33.8s
# 47009 finished: /gpfs/work1/0/wtrcycle/users/jaerts/model_refinement_pub/observations/evaporation/regridded_FLUXCOM/47009_FLUXCOM_evaporation_ref_2008_2015.nc
# 39005
# [########################################] | 100% Completed | 33.1s
# 39005 finished: /gpfs/work1/0/wtrcycle/users/jaerts/model_refinement_pub/observations/evaporation/regridded_FLUXCOM/39005_FLUXCOM_evaporation_ref_2008_2015.nc
# 64006
# [########################################] | 100% Completed | 33.6s
# 64006 finished: /gpfs/work1/0/wtrcycle/users/jaerts/model_refinement_pub/observations/evaporation/regridded_FLUXCOM/64006_FLUXCOM_evaporation_ref_2008_2015.nc
# 37019
# [########################################] | 100% Completed | 33.3s
# 37019 finished: /gpfs/work1/0/wtrcycle/users/jaerts/model_refinement_pub/observations/evaporation/regridded_FLUXCOM/37019_FLUXCOM_evaporation_ref_2008_2015.nc
# 23011
# [########################################] | 100% Completed | 33.6s
# 23011 finished: /gpfs/work1/0/wtrcycle/users/jaerts/model_refinement_pub/observations/evaporation/regridded_FLUXCOM/23011_FLUXCOM_evaporation_ref_2008_2015.nc
# 38017
# [########################################] | 100% Completed | 33.3s
# 38017 finished: /gpfs/work1/0/wtrcycle/users/jaerts/model_refinement_pub/observations/evaporation/regridded_FLUXCOM/38017_FLUXCOM_evaporation_ref_2008_2015.nc
# 65007
# [########################################] | 100% Completed | 33.8s
# 65007 finished: /gpfs/work1/0/wtrcycle/users/jaerts/model_refinement_pub/observations/evaporation/regridded_FLUXCOM/65007_FLUXCOM_evaporation_ref_2008_2015.nc
# 49002
# [########################################] | 100% Completed | 33.8s
# 49002 finished: /gpfs/work1/0/wtrcycle/users/jaerts/model_refinement_pub/observations/evaporation/regridded_FLUXCOM/49002_FLUXCOM_evaporation_ref_2008_2015.nc
# 27077
# [########################################] | 100% Completed | 33.9s
# 27077 finished: /gpfs/work1/0/wtrcycle/users/jaerts/model_refinement_pub/observations/evaporation/regridded_FLUXCOM/27077_FLUXCOM_evaporation_ref_2008_2015.nc
# 39095
# [########################################] | 100% Completed | 34.0s
# 39095 finished: /gpfs/work1/0/wtrcycle/users/jaerts/model_refinement_pub/observations/evaporation/regridded_FLUXCOM/39095_FLUXCOM_evaporation_ref_2008_2015.nc
# 29003
# [########################################] | 100% Completed | 33.9s
# 29003 finished: /gpfs/work1/0/wtrcycle/users/jaerts/model_refinement_pub/observations/evaporation/regridded_FLUXCOM/29003_FLUXCOM_evaporation_ref_2008_2015.nc
# 40033
# [########################################] | 100% Completed | 34.7s
# 40033 finished: /gpfs/work1/0/wtrcycle/users/jaerts/model_refinement_pub/observations/evaporation/regridded_FLUXCOM/40033_FLUXCOM_evaporation_ref_2008_2015.nc
# 42026
# [########################################] | 100% Completed | 34.9s
# 42026 finished: /gpfs/work1/0/wtrcycle/users/jaerts/model_refinement_pub/observations/evaporation/regridded_FLUXCOM/42026_FLUXCOM_evaporation_ref_2008_2015.nc
# 54034
# [########################################] | 100% Completed | 34.3s
# 54034 finished: /gpfs/work1/0/wtrcycle/users/jaerts/model_refinement_pub/observations/evaporation/regridded_FLUXCOM/54034_FLUXCOM_evaporation_ref_2008_2015.nc
# 84020
# [########################################] | 100% Completed | 33.6s
# 84020 finished: /gpfs/work1/0/wtrcycle/users/jaerts/model_refinement_pub/observations/evaporation/regridded_FLUXCOM/84020_FLUXCOM_evaporation_ref_2008_2015.nc
# 39052
# [########################################] | 100% Completed | 34.2s
# 39052 finished: /gpfs/work1/0/wtrcycle/users/jaerts/model_refinement_pub/observations/evaporation/regridded_FLUXCOM/39052_FLUXCOM_evaporation_ref_2008_2015.nc
# 21017
# [########################################] | 100% Completed | 34.3s
# 21017 finished: /gpfs/work1/0/wtrcycle/users/jaerts/model_refinement_pub/observations/evaporation/regridded_FLUXCOM/21017_FLUXCOM_evaporation_ref_2008_2015.nc
# 23016
# [########################################] | 100% Completed | 33.9s
# 23016 finished: /gpfs/work1/0/wtrcycle/users/jaerts/model_refinement_pub/observations/evaporation/regridded_FLUXCOM/23016_FLUXCOM_evaporation_ref_2008_2015.nc
# 28055
# [########################################] | 100% Completed | 33.5s
# 28055 finished: /gpfs/work1/0/wtrcycle/users/jaerts/model_refinement_pub/observations/evaporation/regridded_FLUXCOM/28055_FLUXCOM_evaporation_ref_2008_2015.nc
# 38021
# [########################################] | 100% Completed | 33.9s
# 38021 finished: /gpfs/work1/0/wtrcycle/users/jaerts/model_refinement_pub/observations/evaporation/regridded_FLUXCOM/38021_FLUXCOM_evaporation_ref_2008_2015.nc
# 89002
# [########################################] | 100% Completed | 33.6s
# 89002 finished: /gpfs/work1/0/wtrcycle/users/jaerts/model_refinement_pub/observations/evaporation/regridded_FLUXCOM/89002_FLUXCOM_evaporation_ref_2008_2015.nc
# 37031
# [########################################] | 100% Completed | 33.4s
# 37031 finished: /gpfs/work1/0/wtrcycle/users/jaerts/model_refinement_pub/observations/evaporation/regridded_FLUXCOM/37031_FLUXCOM_evaporation_ref_2008_2015.nc
# 47014
# [########################################] | 100% Completed | 34.1s
# 47014 finished: /gpfs/work1/0/wtrcycle/users/jaerts/model_refinement_pub/observations/evaporation/regridded_FLUXCOM/47014_FLUXCOM_evaporation_ref_2008_2015.nc
# 58008
# [########################################] | 100% Completed | 33.7s
# 58008 finished: /gpfs/work1/0/wtrcycle/users/jaerts/model_refinement_pub/observations/evaporation/regridded_FLUXCOM/58008_FLUXCOM_evaporation_ref_2008_2015.nc
# 37011
# [########################################] | 100% Completed | 33.6s
# 37011 finished: /gpfs/work1/0/wtrcycle/users/jaerts/model_refinement_pub/observations/evaporation/regridded_FLUXCOM/37011_FLUXCOM_evaporation_ref_2008_2015.nc
# 88001
# [########################################] | 100% Completed | 34.0s
# 88001 finished: /gpfs/work1/0/wtrcycle/users/jaerts/model_refinement_pub/observations/evaporation/regridded_FLUXCOM/88001_FLUXCOM_evaporation_ref_2008_2015.nc
# 41022
# [########################################] | 100% Completed | 33.4s
# 41022 finished: /gpfs/work1/0/wtrcycle/users/jaerts/model_refinement_pub/observations/evaporation/regridded_FLUXCOM/41022_FLUXCOM_evaporation_ref_2008_2015.nc
# 47018
# [########################################] | 100% Completed | 34.7s
# 47018 finished: /gpfs/work1/0/wtrcycle/users/jaerts/model_refinement_pub/observations/evaporation/regridded_FLUXCOM/47018_FLUXCOM_evaporation_ref_2008_2015.nc
# 106001
# [########################################] | 100% Completed | 34.7s
# 106001 finished: /gpfs/work1/0/wtrcycle/users/jaerts/model_refinement_pub/observations/evaporation/regridded_FLUXCOM/106001_FLUXCOM_evaporation_ref_2008_2015.nc
# 74006
# [########################################] | 100% Completed | 34.4s
# 74006 finished: /gpfs/work1/0/wtrcycle/users/jaerts/model_refinement_pub/observations/evaporation/regridded_FLUXCOM/74006_FLUXCOM_evaporation_ref_2008_2015.nc
# 33054
# [########################################] | 100% Completed | 33.6s
# 33054 finished: /gpfs/work1/0/wtrcycle/users/jaerts/model_refinement_pub/observations/evaporation/regridded_FLUXCOM/33054_FLUXCOM_evaporation_ref_2008_2015.nc
# 58009
# [########################################] | 100% Completed | 33.3s
# 58009 finished: /gpfs/work1/0/wtrcycle/users/jaerts/model_refinement_pub/observations/evaporation/regridded_FLUXCOM/58009_FLUXCOM_evaporation_ref_2008_2015.nc
# 73009
# [########################################] | 100% Completed | 33.8s
# 73009 finished: /gpfs/work1/0/wtrcycle/users/jaerts/model_refinement_pub/observations/evaporation/regridded_FLUXCOM/73009_FLUXCOM_evaporation_ref_2008_2015.nc
# 28039
# [########################################] | 100% Completed | 34.8s
# 28039 finished: /gpfs/work1/0/wtrcycle/users/jaerts/model_refinement_pub/observations/evaporation/regridded_FLUXCOM/28039_FLUXCOM_evaporation_ref_2008_2015.nc
# 39127
# [########################################] | 100% Completed | 33.9s
# 39127 finished: /gpfs/work1/0/wtrcycle/users/jaerts/model_refinement_pub/observations/evaporation/regridded_FLUXCOM/39127_FLUXCOM_evaporation_ref_2008_2015.nc
# 28060
# [########################################] | 100% Completed | 33.7s
# 28060 finished: /gpfs/work1/0/wtrcycle/users/jaerts/model_refinement_pub/observations/evaporation/regridded_FLUXCOM/28060_FLUXCOM_evaporation_ref_2008_2015.nc
# 38026
# [########################################] | 100% Completed | 33.0s
# 38026 finished: /gpfs/work1/0/wtrcycle/users/jaerts/model_refinement_pub/observations/evaporation/regridded_FLUXCOM/38026_FLUXCOM_evaporation_ref_2008_2015.nc
# 17003
# [########################                ] | 60% Completed | 24.8s
# KeyboardInterrupt
# [########################################] | 100% Completed | 33.8s
# 17003 finished: /gpfs/work1/0/wtrcycle/users/jaerts/model_refinement_pub/observations/evaporation/regridded_FLUXCOM/17003_FLUXCOM_evaporation_ref_2008_2015.nc
# 84026
# [                                        ] | 0% Completed |  0.8s
